# %% [markdown]
# # CS109b Final Project EDA (Milestone 2)

# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv("./../Data/airpred_clean.csv")
df.shape
# Out:
# (21560, 117)

# %% [markdown]
# ### Quick EDA

# %% [markdown]
# The dataset contains 21,560 observations for 117 variables. The data were collected between January 1, 2012 and January 10, 2012 at 2,156 sites, with 10 readings at each site (one reading per day). The 117 variables collected for each site include air pollutant measurements (such as levels of PM2.5, Ozone, and NO2), land use variables (such as road density, restaurant density, and the coverage of tree canopy, shrubland, water, wetlands, developed land, and barren land), surface level meteorological variables (such as precipitation rate, accumulated snow, air temperature, visibility, and soil moisture content), measurements from NASA satellites (such as aerosol products, surface reflectance, Land Surface, and Temperature and Emissivity), and measurements from areas nearby (PM2.5, Ozone, NO2, and temperature of nearby areas).
#
# !!!!! add Eric's code to notebook

# %%
df.head()
# Out:
#    Unnamed: 0  site  year        date  MonitorData  GFEDFireCarbon  \
# 0           1     1  2012  2012-01-01     0.416935        0.000000
# 1           2     2  2012  2012-01-01     0.442172        0.000359
# 2           3     3  2012  2012-01-01     0.406011        0.000000
# 3           4     4  2012  2012-01-01     0.432947        0.000000
# 4           5     5  2012  2012-01-01     0.488368        0.000155
#
#    USElevation_dsc10000  USElevation_max100  USElevation_max10000  \
# 0              0.018435            0.021178              0.018696
# 1              0.109451            0.104439              0.109926
# 2              0.057965            0.058312              0.058324
# 3              0.106229            0.110241              0.106653
# 4              0.061795            0.062083              0.063172
#
#    USElevation_mea100  USElevation_mea10000  USElevation_med100  \
# 0            0.019602              0.018626            0.019591
# 1            0.103569              0.109700            0.103509
# 2            0.057343              0.058225            0.057310
# 3            0.109421              0.106490            0.109357
# 4            0.060269              0.062044            0.060234
#
#    USElevation_med10000  USElevation_min100  USElevation_min10000  \
# 0              0.018642            0.019515              0.018631
# 1              0.109687            0.104080              0.109618
# 2              0.058221            0.055884              0.058251
# 3              0.106492            0.110290              0.106409
# 4              0.062002            0.057363              0.061245
#
#    USElevation_std100  USElevation_std10000  USElevation_bln100  \
# 0            0.024390              0.053644            0.019846
# 1            0.048780              0.136850            0.104265
# 2            0.097561              0.086542            0.059538
# 3            0.048780              0.126846            0.109893
# 4            0.170732              0.136461            0.054799
#
#    USElevation_bln10000  NLCD_Barren100  NLCD_Barren10000  NLCD_Developed100  \
# 0              0.018741             0.0          0.010422           0.111111
# 1              0.110166             0.0          0.010422           0.000000
# 2              0.058599             0.0          0.003417           0.000000
# 3              0.107468             0.0          0.001025           0.000000
# 4              0.062720             0.0          0.002734           0.111111
#
#    NLCD_Developed10000  NLCD_Herbaceous100  NLCD_Herbaceous10000  \
# 0             0.086789                 0.0              0.056136
# 1             0.023897                 1.0              0.097922
# 2             0.234445                 0.0              0.014579
# 3             0.018862                 0.0              0.014924
# 4             0.275059                 0.0              0.012169
#
#    NLCD_Planted100  NLCD_Planted10000  NLCD_Shrubland100  NLCD_Shrubland10000  \
# 0              0.0           0.338143                0.0             0.040721
# 1              0.0           0.218920                0.0             0.052428
# 2              1.0           0.240725                0.0             0.042960
# 3              1.0           0.602191                0.0             0.034918
# 4              0.0           0.082664                0.0             0.019953
#
#    NLCD_Water100  NLCD_Water10000  NLCD_Wetlands100  NLCD_Wetlands10000  \
# 0            0.0         0.173497               0.0            0.133716
# 1            0.0         0.010860               0.0            0.009663
# 2            0.0         0.102004               0.0            0.074432
# 3            0.0         0.002715               0.0            0.006399
# 4            0.0         0.091661               0.0            0.031209
#
#    NLCD_Impervious100  NLCD_Impervious10000  RoadDensity_primaryroads1000  \
# 0                0.01              0.081081                           0.0
# 1                0.00              0.013514                           0.0
# 2                0.00              0.216216                           0.0
# 3                0.00              0.013514                           0.0
# 4                0.19              0.256757                           0.0
#
#    RoadDensity_primaryroads10000  RoadDensity_prisecroads1000  \
# 0                       0.000000                     0.204607
# 1                       0.000000                     0.051356
# 2                       0.000000                     0.242577
# 3                       0.052662                     0.052479
# 4                       0.079085                     0.051523
#
#    RoadDensity_prisecroads10000  RoadDensity_roads1000  \
# 0                      0.142577               0.258635
# 1                      0.087416               0.048106
# 2                      0.383735               0.217309
# 3                      0.108719               0.098395
# 4                      0.329049               0.187514
#
#    Business_Restaurant1000  PM25_Region  Ozone_Region  NO2_Region  \
# 0                 0.001443         0.22      0.136842        0.26
# 1                 0.000000         0.99      0.905263        0.28
# 2                 0.000000         0.50      0.389474        0.44
# 3                 0.000481         0.99      0.389474        0.44
# 4                 0.000000         0.99      0.905263        0.28
#
#    MAIACUS_Optical_Depth_047_Aqua_Nearest4  \
# 0                                 0.099626
# 1                                 0.080908
# 2                                 0.006555
# 3                                 0.072089
# 4                                 0.069496
#
#    MAIACUS_Optical_Depth_055_Aqua_Nearest4  \
# 0                                 0.091537
# 1                                 0.074719
# 2                                 0.004428
# 3                                 0.065953
# 4                                 0.062944
#
#    MAIACUS_Optical_Depth_047_Terra_Nearest4  \
# 0                                  0.132056
# 1                                  0.118863
# 2                                  0.085440
# 3                                  0.104249
# 4                                  0.098915
#
#    MAIACUS_Optical_Depth_055_Terra_Nearest4  MAIACUS_cosVZA_Aqua_Nearest  \
# 0                                  0.125613                     0.239008
# 1                                  0.115201                     0.034217
# 2                                  0.080474                     0.161334
# 3                                  0.098855                     0.042173
# 4                                  0.094099                     0.040719
#
#    MAIACUS_cosVZA_Terra_Nearest  REANALYSIS_hpbl_DailyMax  \
# 0                      0.899368                  0.151213
# 1                      0.979498                  0.295865
# 2                      0.836494                  0.247272
# 3                      0.961900                  0.259161
# 4                      0.963608                  0.263912
#
#    REANALYSIS_shum_2m_DailyMax  REANALYSIS_windspeed_10m_DailyMax  \
# 0                     0.701406                           0.266299
# 1                     0.522468                           0.330234
# 2                     0.490049                           0.335338
# 3                     0.474846                           0.321007
# 4                     0.474182                           0.324997
#
#    REANALYSIS_prate_DailyMax  REANALYSIS_vis_DailyMax  \
# 0                   0.001647                 0.999846
# 1                   0.002021                 0.999846
# 2                   0.006631                 0.999846
# 3                   0.005717                 0.999846
# 4                   0.004812                 0.999846
#
#    REANALYSIS_apcp_DailyMean  REANALYSIS_dlwrf_DailyMean  \
# 0                   0.000295                    0.796662
# 1                   0.000815                    0.646170
# 2                   0.003052                    0.578958
# 3                   0.007475                    0.593158
# 4                   0.004093                    0.608548
#
#    REANALYSIS_dswrf_DailyMean  REANALYSIS_evap_DailyMean  \
# 0                    0.415671                   0.210459
# 1                    0.418643                   0.211815
# 2                    0.541302                   0.233725
# 3                    0.433217                   0.221502
# 4                    0.435217                   0.216438
#
#    REANALYSIS_hpbl_DailyMean  REANALYSIS_gflux_DailyMean  \
# 0                   0.092917                    0.420149
# 1                   0.191179                    0.461199
# 2                   0.268363                    0.464973
# 3                   0.232148                    0.468564
# 4                   0.238385                    0.468617
#
#    REANALYSIS_lhtfl_DailyMean  REANALYSIS_shtfl_DailyMean  \
# 0                    0.789495                    0.707847
# 1                    0.788211                    0.724710
# 2                    0.766292                    0.735263
# 3                    0.778459                    0.743275
# 4                    0.783540                    0.728740
#
#    REANALYSIS_shum_2m_DailyMean  REANALYSIS_snowc_DailyMean  \
# 0                      0.706608                         0.0
# 1                      0.403331                         0.0
# 2                      0.381732                         0.0
# 3                      0.364412                         0.0
# 4                      0.363929                         0.0
#
#    REANALYSIS_soilm_DailyMean  REANALYSIS_tcdc_DailyMean  \
# 0                    0.327076                   0.390313
# 1                    0.364911                   0.406250
# 2                    0.567912                   0.258437
# 3                    0.496590                   0.355625
# 4                    0.435182                   0.346250
#
#    REANALYSIS_windspeed_10m_DailyMean  REANALYSIS_weasd_DailyMean  \
# 0                            0.096916                         0.0
# 1                            0.115592                         0.0
# 2                            0.151737                         0.0
# 3                            0.127266                         0.0
# 4                            0.133885                         0.0
#
#    REANALYSIS_prate_DailyMean  REANALYSIS_vis_DailyMean  \
# 0                    0.002711                  0.806191
# 1                    0.002948                  0.842125
# 2                    0.005083                  0.823689
# 3                    0.006032                  0.934615
# 4                    0.005794                  0.939614
#
#    REANALYSIS_hpbl_DailyMin  REANALYSIS_shum_2m_DailyMin  \
# 0                  0.005677                     0.684593
# 1                  0.047403                     0.292937
# 2                  0.074055                     0.299535
# 3                  0.051307                     0.264432
# 4                  0.049085                     0.269560
#
#    REANALYSIS_windspeed_10m_DailyMin  REANALYSIS_prate_DailyMin  \
# 0                           0.143037                   0.008022
# 1                           0.059501                   0.006226
# 2                           0.128134                   0.006226
# 3                           0.077768                   0.006226
# 4                           0.085404                   0.006226
#
#    REANALYSIS_vis_DailyMin  REANALYSIS_hpbl_1Day  REANALYSIS_shum_2m_1Day  \
# 0                 0.609986              0.116123                 0.660251
# 1                 0.327516              0.156187                 0.378341
# 2                 0.112539              0.095957                 0.322121
# 3                 0.714974              0.143847                 0.332795
# 4                 0.649981              0.146923                 0.341948
#
#    REANALYSIS_windspeed_10m_1Day  REANALYSIS_prate_1Day  REANALYSIS_vis_1Day  \
# 0                            NaN               0.001353             0.786548
# 1                            NaN               0.001353             0.994030
# 2                            NaN               0.001353             0.999967
# 3                            NaN               0.001353             0.999967
# 4                            NaN               0.001353             0.999967
#
#    REANALYSIS_air_sfc_DailyMin  REANALYSIS_air_sfc_DailyMean  \
# 0                     0.864714                      0.897917
# 1                     0.704544                      0.782077
# 2                     0.723934                      0.777259
# 3                     0.691067                      0.754722
# 4                     0.690002                      0.757629
#
#    REANALYSIS_air_sfc_DailyMax  MOD04L2_550   MOD09A1  \
# 0                     0.772420     0.072029  0.048138
# 1                     0.740417     0.091182  0.033610
# 2                     0.700166     0.065408  0.041473
# 3                     0.699971     0.069583  0.042040
# 4                     0.716500     0.088118  0.036239
#
#    MOD11A1_LST_Day_1km_Nearest4  MOD11A1_LST_Night_1km_Nearest4  \
# 0                      0.663175                        0.724703
# 1                      0.588771                        0.560182
# 2                      0.595505                        0.661201
# 3                      0.572620                        0.584188
# 4                      0.582349                        0.594837
#
#    MOD11A1_Clear_day_cov_Nearest4  MOD11A1_Clear_night_cov_Nearest4  \
# 0                        0.145248                          0.649471
# 1                        0.485803                          0.646519
# 2                        0.429803                          0.592467
# 3                        0.505852                          0.856886
# 4                        0.504291                          0.637596
#
#    MOD13A2_Nearest4  Nearby_Peak2_NO2  Nearby_Peak2_PM25  Nearby_Peak2_Ozone  \
# 0          0.559229          0.070216           0.043436            0.533456
# 1          0.609793          0.095858           0.063371            0.494272
# 2          0.481108          0.108908           0.042391            0.502992
# 3          0.617881          0.091255           0.066151            0.467742
# 4          0.140186          0.080860           0.053639            0.471808
#
#    Nearby_Peak2Lag1_NO2  Nearby_Peak2Lag1_PM25  Nearby_Peak2Lag1_Ozone  \
# 0              0.070216               0.043436                0.533456
# 1              0.095858               0.063371                0.494272
# 2              0.108908               0.042391                0.502992
# 3              0.091255               0.066151                0.467742
# 4              0.080860               0.053639                0.471808
#
#    Nearby_Peak2Lag3_NO2  Nearby_Peak2Lag3_PM25  Nearby_Peak2Lag3_Ozone  \
# 0              0.070216               0.043436                0.533456
# 1              0.095858               0.063371                0.494272
# 2              0.108908               0.042391                0.502992
# 3              0.091255               0.066151                0.467742
# 4              0.080860               0.053639                0.471808
#
#    Nearby_Peak2_MaxTemperature  Nearby_Peak2_MeanTemperature  \
# 0                     0.642788                      0.652465
# 1                     0.557745                      0.537851
# 2                     0.548226                      0.534536
# 3                     0.572237                      0.560523
# 4                     0.540442                      0.529652
#
#    Nearby_Peak2_MinTemperature  Nearby_Peak2Lag1_MaxTemperature  \
# 0                     0.657992                         0.638144
# 1                     0.550815                         0.553226
# 2                     0.555665                         0.543735
# 3                     0.574358                         0.567680
# 4                     0.547720                         0.535977
#
#    Nearby_Peak2Lag1_MeanTemperature  Nearby_Peak2Lag1_MinTemperature  \
# 0                          0.653322                         0.658382
# 1                          0.538707                         0.551179
# 2                          0.535391                         0.556031
# 3                          0.561385                         0.574730
# 4                          0.530506                         0.548083
#
#    Nearby_Peak2Lag3_MaxTemperature  Nearby_Peak2Lag3_MeanTemperature  \
# 0                         0.637137                          0.652721
# 1                         0.552202                          0.538067
# 2                         0.542713                          0.534750
# 3                         0.566656                          0.560749
# 4                         0.534956                          0.529864
#
#    Nearby_Peak2Lag3_MinTemperature  OMAEROe_UVAerosolIndex_Mean  \
# 0                         0.658382                     0.686237
# 1                         0.551179                     0.546198
# 2                         0.556031                     0.602502
# 3                         0.574730                     0.305101
# 4                         0.548083                     0.352262
#
#    OMAEROe_VISAerosolIndex_Mean  OMAERUVd_UVAerosolIndex_Mean  \
# 0                      0.501368                      0.209643
# 1                      0.703382                      0.277030
# 2                      0.327473                      0.194386
# 3                      0.433254                      0.234205
# 4                      0.509693                      0.234205
#
#    OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean    OMO3PR  \
# 0                                        0.801457  0.627457
# 1                                        0.768112  0.631224
# 2                                        0.727493  0.585309
# 3                                        0.743635  0.591333
# 4                                        0.750772  0.601661
#
#    OMSO2e_ColumnAmountSO2_PBL_Mean  OMTO3e_ColumnAmountO3  OMUVBd_UVindex_Mean
# 0                         0.482187               0.149777             0.378225
# 1                         0.562460               0.192401             0.288462
# 2                         0.432882               0.249783             0.299520
# 3                         0.400335               0.226691             0.304247
# 4                         0.477521               0.214885             0.304247

# %% [markdown]
# ### Clean data

# %% [markdown]
# To clean the data, we first removed columns that provide little information (Unnamed: 0, a column of row numbers, and year, which is 2012 for all observations). Next, we removed columns with many NA values (REANALYSIS_windspeed_10m_1Day, MonitorData, RoadDensity_prisecroads10000, RoadDensity_prisecroads1000, and RoadDensity_roads1000, which had NA values for 21560, 16199, 300, 300, and 270 observations, respectively). Then, we removed the remaining rows with NA values, dropping 130 rows. Lastly, we converted the date column to the day in January 2012 so that its values are more suitable for analyses and modeling without losing any information. The cleaned data set contains 21430 observations for 110 variables. These measurements cover 2143 sites, with 10 measurements for each site, one for each day between January 1, 2012 and January 10, 2012. Following analyses are performed using the cleaned dataset.

# %%
#check NA values
df.isnull().sum(axis = 0).sort_values(ascending=False)
# Out:
# REANALYSIS_windspeed_10m_1Day                     21560
# MonitorData                                       16199
# RoadDensity_prisecroads10000                        300
# RoadDensity_prisecroads1000                         300
# RoadDensity_roads1000                               270
# USElevation_min100                                   50
# USElevation_mea100                                   40
# USElevation_bln100                                   40
# NLCD_Barren100                                       30
# NLCD_Planted100                                      30
# NLCD_Developed100                                    30
# NLCD_Shrubland100                                    30
# NLCD_Water100                                        30
# NLCD_Wetlands100                                     30
# USElevation_med100                                   30
# NLCD_Herbaceous100                                   30
# REANALYSIS_prate_DailyMean                           20
# REANALYSIS_weasd_DailyMean                           20
# REANALYSIS_snowc_DailyMean                           20
# REANALYSIS_vis_DailyMean                             20
# REANALYSIS_windspeed_10m_DailyMean                   20
# REANALYSIS_hpbl_DailyMin                             20
# REANALYSIS_tcdc_DailyMean                            20
# REANALYSIS_shum_2m_DailyMin                          20
# REANALYSIS_windspeed_10m_DailyMin                    20
# REANALYSIS_evap_DailyMean                            20
# REANALYSIS_shum_2m_DailyMean                         20
# REANALYSIS_shtfl_DailyMean                           20
# REANALYSIS_vis_DailyMin                              20
# REANALYSIS_lhtfl_DailyMean                           20
# REANALYSIS_hpbl_DailyMean                            20
# REANALYSIS_dswrf_DailyMean                           20
# REANALYSIS_dlwrf_DailyMean                           20
# REANALYSIS_apcp_DailyMean                            20
# REANALYSIS_vis_DailyMax                              20
# REANALYSIS_prate_DailyMax                            20
# REANALYSIS_windspeed_10m_DailyMax                    20
# REANALYSIS_shum_2m_DailyMax                          20
# REANALYSIS_hpbl_DailyMax                             20
# REANALYSIS_prate_DailyMin                            20
# REANALYSIS_prate_1Day                                20
# REANALYSIS_hpbl_1Day                                 20
# USElevation_bln10000                                 20
# USElevation_dsc10000                                 20
# USElevation_max100                                   20
# USElevation_max10000                                 20
# USElevation_mea10000                                 20
# USElevation_med10000                                 20
# USElevation_min10000                                 20
# USElevation_std100                                   20
# REANALYSIS_shum_2m_1Day                              20
# USElevation_std10000                                 20
# REANALYSIS_air_sfc_DailyMin                          20
# REANALYSIS_vis_1Day                                  20
# REANALYSIS_air_sfc_DailyMean                         20
# REANALYSIS_air_sfc_DailyMax                          20
# NLCD_Shrubland10000                                  10
# NLCD_Developed10000                                  10
# NLCD_Water10000                                      10
# NLCD_Herbaceous10000                                 10
# NLCD_Planted10000                                    10
# NLCD_Wetlands10000                                   10
# NLCD_Barren10000                                     10
# NLCD_Impervious10000                                  0
# NLCD_Impervious100                                    0
# Ozone_Region                                          0
# GFEDFireCarbon                                        0
# RoadDensity_primaryroads1000                          0
# RoadDensity_primaryroads10000                         0
# date                                                  0
# year                                                  0
# site                                                  0
# Business_Restaurant1000                               0
# PM25_Region                                           0
# OMUVBd_UVindex_Mean                                   0
# NO2_Region                                            0
# Nearby_Peak2Lag1_MinTemperature                       0
# Nearby_Peak2Lag3_NO2                                  0
# Nearby_Peak2Lag3_PM25                                 0
# Nearby_Peak2Lag3_Ozone                                0
# Nearby_Peak2_MaxTemperature                           0
# Nearby_Peak2_MeanTemperature                          0
# Nearby_Peak2_MinTemperature                           0
# Nearby_Peak2Lag1_MaxTemperature                       0
# Nearby_Peak2Lag1_MeanTemperature                      0
# Nearby_Peak2Lag3_MaxTemperature                       0
# MAIACUS_Optical_Depth_047_Aqua_Nearest4               0
# Nearby_Peak2Lag3_MeanTemperature                      0
# Nearby_Peak2Lag3_MinTemperature                       0
# OMAEROe_UVAerosolIndex_Mean                           0
# OMAEROe_VISAerosolIndex_Mean                          0
# OMAERUVd_UVAerosolIndex_Mean                          0
# OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean        0
# OMO3PR                                                0
# OMSO2e_ColumnAmountSO2_PBL_Mean                       0
# Nearby_Peak2Lag1_Ozone                                0
# Nearby_Peak2Lag1_PM25                                 0
# Nearby_Peak2Lag1_NO2                                  0
# Nearby_Peak2_Ozone                                    0
# MAIACUS_Optical_Depth_055_Aqua_Nearest4               0
# MAIACUS_Optical_Depth_047_Terra_Nearest4              0
# MAIACUS_Optical_Depth_055_Terra_Nearest4              0
# MAIACUS_cosVZA_Aqua_Nearest                           0
# MAIACUS_cosVZA_Terra_Nearest                          0
# OMTO3e_ColumnAmountO3                                 0
# REANALYSIS_gflux_DailyMean                            0
# REANALYSIS_soilm_DailyMean                            0
# MOD04L2_550                                           0
# MOD09A1                                               0
# MOD11A1_LST_Day_1km_Nearest4                          0
# MOD11A1_LST_Night_1km_Nearest4                        0
# MOD11A1_Clear_day_cov_Nearest4                        0
# MOD11A1_Clear_night_cov_Nearest4                      0
# MOD13A2_Nearest4                                      0
# Nearby_Peak2_NO2                                      0
# Nearby_Peak2_PM25                                     0
# Unnamed: 0                                            0
# dtype: int64

# %%
#####remove NAs

#drop columns
cols = list(df.columns)
cols.remove('Unnamed: 0') #just a column of integers 1-21560
cols.remove('REANALYSIS_windspeed_10m_1Day') #21560 NA values (all NA values)
cols.remove('MonitorData') #16199 NA values
cols.remove('RoadDensity_prisecroads10000') #300 NA values
cols.remove('RoadDensity_prisecroads1000') #300 NA values
cols.remove('RoadDensity_roads1000') #270 NA values
cols.remove('year') #2012 for all rows
data = df[cols]

#drop remaining rows with NA values --- 130 rows
data = data.dropna()

#check
print('shape, original data:', df.shape)
print('shape, cleaned data:', data.shape)
print('number of NA values, cleaned data:', data.isnull().sum(axis = 0).sum()) #should be 0
print('number of sites values, cleaned data:', len(data.site.value_counts()))
print('number of observations per site, cleaned data:', data.site.value_counts().value_counts().index[0])

#####convert date to day in Jan2012
data['date'] = pd.to_datetime(data['date']).dt.day
#data['date'].value_counts() #check that there are 2143 (# of sites) observations for each day
# Out:
# shape, original data: (21560, 117)
# shape, cleaned data: (21430, 110)
# number of NA values, cleaned data: 0
# number of sites values, cleaned data: 2143
# number of observations per site, cleaned data: 10

# %% [markdown]
# ### Examine all variables

# %% [markdown]
# Aside from ```site``` and ```date```, all the variables in the dataset are continuous, numerical variables. The variables can be classified into the categories shown below. In addition, summary statistics of each variable are shown below. To quickly examine the pairwise relationships between each variable, we calculated and visualized the correlation matrix. The correlation matrix indicates that some variables, such as ```REANALYSIS_air_sfc_DailyMax``` and ```OMTO3e_ColumnAmountO3``` (correlation = -0.71), ```USElevation_mea100``` and ```USElevation_bln10000``` (correlation = 0.99), or ```USElevation_bln100``` and ```USElevation_dsc10000``` (correlation = 0.99), are strongly correlated, indicating potential issues of multicollinearity among the predictors.

# %% [markdown]
# **Variable categories:**
#
# **Data collection information**
# - site
# - date
#
# **GFED forest fire**
# - GFEDFireCarbon
#
# **Land use**
# - USElevation_dsc10000
# - USElevation_max100
# - USElevation_max10000
# - USElevation_mea100
# - USElevation_mea10000
# - USElevation_med100
# - USElevation_med10000
# - USElevation_min100
# - USElevation_min10000
# - USElevation_std100
# - USElevation_std10000
# - USElevation_bln100
# - USElevation_bln10000
# - NLCD_Barren100
# - NLCD_Barren10000
# - NLCD_Developed100
# - NLCD_Developed10000
# - NLCD_Herbaceous100
# - NLCD_Herbaceous10000
# - NLCD_Planted100
# - NLCD_Planted10000
# - NLCD_Shrubland100
# - NLCD_Shrubland10000
# - NLCD_Water100
# - NLCD_Water10000
# - NLCD_Wetlands100
# - NLCD_Wetlands10000
# - NLCD_Impervious100
# - NLCD_Impervious10000
# - RoadDensity_primaryroads1000
# - RoadDensity_primaryroads10000
# - Business_Restaurant1000
#
# **Pollutants**
# - PM25_Region
# - Ozone_Region
# - NO2_Region
#
# **MAIAC AOD**
# - MAIACUS_Optical_Depth_047_Aqua_Nearest4
# - MAIACUS_Optical_Depth_055_Aqua_Nearest4
# - MAIACUS_Optical_Depth_047_Terra_Nearest4
# - MAIACUS_Optical_Depth_055_Terra_Nearest4
# - MAIACUS_cosVZA_Aqua_Nearest
# - MAIACUS_cosVZA_Terra_Nearest
#
# **Surface Level Meteorological Variables**
# - REANALYSIS_hpbl_DailyMax
# - REANALYSIS_shum_2m_DailyMax
# - REANALYSIS_windspeed_10m_DailyMax
# - REANALYSIS_prate_DailyMax
# - REANALYSIS_vis_DailyMax
# - REANALYSIS_apcp_DailyMean
# - REANALYSIS_dlwrf_DailyMean
# - REANALYSIS_dswrf_DailyMean
# - REANALYSIS_evap_DailyMean
# - REANALYSIS_hpbl_DailyMean
# - REANALYSIS_gflux_DailyMean
# - REANALYSIS_lhtfl_DailyMean
# - REANALYSIS_shtfl_DailyMean
# - REANALYSIS_shum_2m_DailyMean
# - REANALYSIS_snowc_DailyMean
# - REANALYSIS_soilm_DailyMean
# - REANALYSIS_tcdc_DailyMean
# - REANALYSIS_windspeed_10m_DailyMean
# - REANALYSIS_weasd_DailyMean
# - REANALYSIS_prate_DailyMean
# - REANALYSIS_vis_DailyMean
# - REANALYSIS_hpbl_DailyMin
# - REANALYSIS_shum_2m_DailyMin
# - REANALYSIS_windspeed_10m_DailyMin
# - REANALYSIS_prate_DailyMin
# - REANALYSIS_vis_DailyMin
# - REANALYSIS_hpbl_1Day
# - REANALYSIS_shum_2m_1Day
# - REANALYSIS_prate_1Day
# - REANALYSIS_vis_1Day
# - REANALYSIS_air_sfc_DailyMin
# - REANALYSIS_air_sfc_DailyMean
# - REANALYSIS_air_sfc_DailyMax
#
# **Measurements from NASA satellites**
#
# MOD04 - NASA aerosol products --- https://modis.gsfc.nasa.gov/data/dataprod/mod04.php
#
# MOD09A1 - NASA surface reflectance --- https://modis.gsfc.nasa.gov/data/dataprod/mod09.php
#
# MOD11A1 - NASA Land Surface Temperature and Emissivity --- https://modis.gsfc.nasa.gov/data/dataprod/mod11.php
#
# MOD13A2 - NASA Vegetation Index Products --- https://modis.gsfc.nasa.gov/data/dataprod/mod13.php
# - MOD04L2_550
# - MOD09A1
# - MOD11A1_LST_Day_1km_Nearest4
# - MOD11A1_LST_Night_1km_Nearest4
# - MOD11A1_Clear_day_cov_Nearest4
# - MOD11A1_Clear_night_cov_Nearest4
# - MOD13A2_Nearest4
#
# **Nearby monitoring data**
# - Nearby_Peak2_NO2
# - Nearby_Peak2_PM25
# - Nearby_Peak2_Ozone
# - Nearby_Peak2Lag1_NO2
# - Nearby_Peak2Lag1_PM25
# - Nearby_Peak2Lag1_Ozone
# - Nearby_Peak2Lag3_NO2
# - Nearby_Peak2Lag3_PM25
# - Nearby_Peak2Lag3_Ozone
# - Nearby_Peak2_MaxTemperature
# - Nearby_Peak2_MeanTemperature
# - Nearby_Peak2_MinTemperature
# - Nearby_Peak2Lag1_MaxTemperature
# - Nearby_Peak2Lag1_MeanTemperature
# - Nearby_Peak2Lag1_MinTemperature
# - Nearby_Peak2Lag3_MaxTemperature
# - Nearby_Peak2Lag3_MeanTemperature
# - Nearby_Peak2Lag3_MinTemperature
#
# **OMI (ozone monitoring instrument)**
# - OMAEROe_UVAerosolIndex_Mean
# - OMAEROe_VISAerosolIndex_Mean
# - OMAERUVd_UVAerosolIndex_Mean
# - OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean
# - OMO3PR
# - OMSO2e_ColumnAmountSO2_PBL_Mean
# - OMTO3e_ColumnAmountO3
# - OMUVBd_UVindex_Mean

# %%
#summary statistics of each variable
data.describe()
# Out:
#                site          date  GFEDFireCarbon  USElevation_dsc10000  \
# count  21430.000000  21430.000000    21430.000000          21430.000000
# mean    1079.177322      5.500000        0.001338              0.142283
# std      622.355285      2.872348        0.020436              0.171118
# min        1.000000      1.000000        0.000000              0.000000
# 25%      539.000000      3.000000        0.000000              0.033277
# 50%     1079.000000      5.500000        0.000000              0.078444
# 75%     1619.000000      8.000000        0.000000              0.141088
# max     2156.000000     10.000000        0.918922              1.000000
#
#        USElevation_max100  USElevation_max10000  USElevation_mea100  \
# count        21430.000000          21430.000000        21430.000000
# mean             0.135651              0.142287            0.135154
# std              0.165580              0.169604            0.166489
# min              0.000000              0.000000            0.000000
# 25%              0.031332              0.034149            0.030427
# 50%              0.073687              0.078957            0.072264
# 75%              0.133449              0.142338            0.133411
# max              1.000000              1.000000            1.000000
#
#        USElevation_mea10000  USElevation_med100  USElevation_med10000  \
# count          21430.000000        21430.000000          21430.000000
# mean               0.142504            0.135084              0.142505
# std                0.171090            0.166413              0.171093
# min                0.000000            0.000000              0.000000
# 25%                0.033543            0.030409              0.033545
# 50%                0.078706            0.072222              0.078718
# 75%                0.141326            0.133333              0.141309
# max                1.000000            1.000000              1.000000
#
#        USElevation_min100  USElevation_min10000  USElevation_std100  \
# count        21430.000000          21430.000000        21430.000000
# mean             0.135284              0.142859            0.075834
# std              0.167667              0.172581            0.088131
# min              0.000000              0.000000            0.000000
# 25%              0.029568              0.033061            0.024390
# 50%              0.071851              0.078952            0.048780
# 75%              0.133057              0.142326            0.073171
# max              1.000000              1.000000            1.000000
#
#        USElevation_std10000  USElevation_bln100  USElevation_bln10000  \
# count          21430.000000        21430.000000          21430.000000
# mean               0.139780            0.136643              0.142723
# std                0.131310            0.168109              0.171195
# min                0.000000            0.000000              0.000000
# 25%                0.064266            0.031102              0.033700
# 50%                0.090154            0.073756              0.078998
# 75%                0.159525            0.133886              0.141746
# max                1.000000            1.000000              1.000000
#
#        NLCD_Barren100  NLCD_Barren10000  NLCD_Developed100  \
# count    21430.000000      21430.000000       21430.000000
# mean         0.002333          0.011453           0.420542
# std          0.048248          0.041144           0.376704
# min          0.000000          0.000000           0.000000
# 25%          0.000000          0.000342           0.000000
# 50%          0.000000          0.002050           0.388889
# 75%          0.000000          0.009226           0.722222
# max          1.000000          1.000000           1.000000
#
#        NLCD_Developed10000  NLCD_Herbaceous100  NLCD_Herbaceous10000  \
# count         21430.000000        21430.000000          21430.000000
# mean              0.261560            0.043397              0.059034
# std               0.238077            0.203754              0.128047
# min               0.000000            0.000000              0.000000
# 25%               0.034403            0.000000              0.002985
# 50%               0.208604            0.000000              0.011939
# 75%               0.427832            0.000000              0.045345
# max               1.000000            1.000000              1.000000
#
#        NLCD_Planted100  NLCD_Planted10000  NLCD_Shrubland100  \
# count     21430.000000       21430.000000       21430.000000
# mean          0.085861           0.147810           0.050397
# std           0.280165           0.212016           0.218767
# min           0.000000           0.000000           0.000000
# 25%           0.000000           0.003688           0.000000
# 50%           0.000000           0.043068           0.000000
# 75%           0.000000           0.211760           0.000000
# max           1.000000           1.000000           1.000000
#
#        NLCD_Shrubland10000  NLCD_Water100  NLCD_Water10000  NLCD_Wetlands100  \
# count         21430.000000   21430.000000     21430.000000      21430.000000
# mean              0.077097       0.007000         0.071815          0.014466
# std               0.167087       0.083372         0.127410          0.119403
# min               0.000000       0.000000         0.000000          0.000000
# 25%               0.000611       0.000000         0.003361          0.000000
# 50%               0.006923       0.000000         0.017841          0.000000
# 75%               0.060369       0.000000         0.074208          0.000000
# max               1.000000       1.000000         1.000000          1.000000
#
#        NLCD_Wetlands10000  NLCD_Impervious100  NLCD_Impervious10000  \
# count        21430.000000        21430.000000          21430.000000
# mean             0.056991            0.374447              0.252305
# std              0.103193            0.343579              0.235206
# min              0.000000            0.000000              0.000000
# 25%              0.002481            0.000000              0.027027
# 50%              0.019196            0.330000              0.202703
# 75%              0.064638            0.700000              0.418919
# max              1.000000            1.000000              1.000000
#
#        RoadDensity_primaryroads1000  RoadDensity_primaryroads10000  \
# count                  21430.000000                   21430.000000
# mean                       0.059640                       0.133529
# std                        0.139298                       0.153048
# min                        0.000000                       0.000000
# 25%                        0.000000                       0.000000
# 50%                        0.000000                       0.081647
# 75%                        0.000000                       0.215981
# max                        1.000000                       1.000000
#
#        Business_Restaurant1000   PM25_Region  Ozone_Region    NO2_Region  \
# count             21430.000000  21430.000000  21430.000000  21430.000000
# mean                  0.013398      0.524069      0.536258      0.526001
# std                   0.048185      0.285876      0.290025      0.295478
# min                   0.000000      0.000000      0.000000      0.000000
# 25%                   0.000000      0.310000      0.284211      0.280000
# 50%                   0.002885      0.530000      0.578947      0.560000
# 75%                   0.013224      0.770000      0.789474      0.780000
# max                   1.000000      1.000000      1.000000      1.000000
#
#        MAIACUS_Optical_Depth_047_Aqua_Nearest4  \
# count                             21430.000000
# mean                                  0.076605
# std                                   0.057669
# min                                  -0.063459
# 25%                                   0.030690
# 50%                                   0.068939
# 75%                                   0.111368
# max                                   0.512343
#
#        MAIACUS_Optical_Depth_055_Aqua_Nearest4  \
# count                             21430.000000
# mean                                  0.072560
# std                                   0.055694
# min                                  -0.059834
# 25%                                   0.028171
# 50%                                   0.064540
# 75%                                   0.105850
# max                                   0.512337
#
#        MAIACUS_Optical_Depth_047_Terra_Nearest4  \
# count                              21430.000000
# mean                                   0.119287
# std                                    0.074630
# min                                   -0.028505
# 25%                                    0.064242
# 50%                                    0.114738
# 75%                                    0.163549
# max                                    0.825821
#
#        MAIACUS_Optical_Depth_055_Terra_Nearest4  MAIACUS_cosVZA_Aqua_Nearest  \
# count                              21430.000000                 21430.000000
# mean                                   0.117896                     0.578513
# std                                    0.075492                     0.303217
# min                                   -0.025545                     0.000000
# 25%                                    0.062648                     0.306672
# 50%                                    0.113102                     0.596492
# 75%                                    0.161143                     0.866724
# max                                    0.858705                     1.000000
#
#        MAIACUS_cosVZA_Terra_Nearest  REANALYSIS_hpbl_DailyMax  \
# count                  21430.000000              21430.000000
# mean                       0.579189                  0.207946
# std                        0.300624                  0.095056
# min                        0.000000                  0.006839
# 25%                        0.310952                  0.135112
# 50%                        0.594567                  0.194100
# 75%                        0.863147                  0.264989
# max                        1.000000                  0.647702
#
#        REANALYSIS_shum_2m_DailyMax  REANALYSIS_windspeed_10m_DailyMax  \
# count                 21430.000000                       21430.000000
# mean                      0.255784                           0.201992
# std                       0.151197                           0.126272
# min                       0.005301                           0.000014
# 25%                       0.165707                           0.105619
# 50%                       0.206020                           0.190190
# 75%                       0.300290                           0.271150
# max                       0.967386                           0.799743
#
#        REANALYSIS_prate_DailyMax  REANALYSIS_vis_DailyMax  \
# count               21430.000000             21430.000000
# mean                    0.009672                 0.989112
# std                     0.037831                 0.078781
# min                     0.000000                 0.000000
# 25%                     0.001844                 0.999846
# 50%                     0.002136                 0.999871
# 75%                     0.002581                 0.999878
# max                     0.988124                 0.999922
#
#        REANALYSIS_apcp_DailyMean  REANALYSIS_dlwrf_DailyMean  \
# count               21430.000000                21430.000000
# mean                    0.006412                    0.456191
# std                     0.031032                    0.132848
# min                     0.000000                    0.107420
# 25%                     0.000007                    0.372043
# 50%                     0.000121                    0.434140
# 75%                     0.001197                    0.514362
# max                     0.716233                    0.992694
#
#        REANALYSIS_dswrf_DailyMean  REANALYSIS_evap_DailyMean  \
# count                21430.000000               21430.000000
# mean                     0.427331                   0.206687
# std                      0.150390                   0.041381
# min                      0.000000                   0.054935
# 25%                      0.329814                   0.187319
# 50%                      0.431010                   0.197819
# 75%                      0.538758                   0.212765
# max                      0.907989                   1.000000
#
#        REANALYSIS_hpbl_DailyMean  REANALYSIS_gflux_DailyMean  \
# count               21430.000000                21430.000000
# mean                    0.182288                    0.509659
# std                     0.113149                    0.103850
# min                     0.000000                    0.213700
# 25%                     0.097544                    0.450494
# 50%                     0.153193                    0.487980
# 75%                     0.234401                    0.537050
# max                     0.725066                    1.624786
#
#        REANALYSIS_lhtfl_DailyMean  REANALYSIS_shtfl_DailyMean  \
# count                21430.000000                21430.000000
# mean                     0.793302                    0.725642
# std                      0.041382                    0.049366
# min                      0.000000                    0.094231
# 25%                      0.787249                    0.703845
# 50%                      0.802162                    0.729020
# 75%                      0.812676                    0.752776
# max                      0.945058                    1.000000
#
#        REANALYSIS_shum_2m_DailyMean  REANALYSIS_snowc_DailyMean  \
# count                  21430.000000                21430.000000
# mean                       0.221528                    0.036498
# std                        0.146471                    0.166864
# min                        0.005216                    0.000000
# 25%                        0.135485                    0.000000
# 50%                        0.182006                    0.000000
# 75%                        0.248496                    0.000000
# max                        0.989233                    1.000000
#
#        REANALYSIS_soilm_DailyMean  REANALYSIS_tcdc_DailyMean  \
# count                21430.000000               21430.000000
# mean                     0.481570                   0.337264
# std                      0.140934                   0.272544
# min                     -0.208953                   0.000000
# 25%                      0.381999                   0.096250
# 50%                      0.465060                   0.280781
# 75%                      0.581731                   0.538438
# max                      1.000000                   1.000000
#
#        REANALYSIS_windspeed_10m_DailyMean  REANALYSIS_weasd_DailyMean  \
# count                        21430.000000                21430.000000
# mean                             0.156793                    0.014867
# std                              0.111788                    0.065064
# min                              0.000000                    0.000000
# 25%                              0.065813                    0.000000
# 50%                              0.142722                    0.000000
# 75%                              0.219322                    0.001972
# max                              0.815895                    0.892534
#
#        REANALYSIS_prate_DailyMean  REANALYSIS_vis_DailyMean  \
# count                21430.000000              21430.000000
# mean                     0.008021                  0.908801
# std                      0.030125                  0.172339
# min                      0.001043                  0.000000
# 25%                      0.001649                  0.898149
# 50%                      0.002610                  0.999882
# 75%                      0.003190                  0.999922
# max                      0.759784                  0.999949
#
#        REANALYSIS_hpbl_DailyMin  REANALYSIS_shum_2m_DailyMin  \
# count              21430.000000                 21430.000000
# mean                   0.127293                     0.196627
# std                    0.120599                     0.143060
# min                    0.000463                     0.004417
# 25%                    0.046645                     0.114010
# 50%                    0.083394                     0.163893
# 75%                    0.167425                     0.219015
# max                    0.754885                     0.985691
#
#        REANALYSIS_windspeed_10m_DailyMin  REANALYSIS_prate_DailyMin  \
# count                       21430.000000               21430.000000
# mean                            0.140073                   0.008511
# std                             0.101399                   0.007340
# min                             0.000004                   0.005334
# 25%                             0.064798                   0.006226
# 50%                             0.123113                   0.007300
# 75%                             0.190732                   0.009928
# max                             1.000000                   0.437795
#
#        REANALYSIS_vis_DailyMin  REANALYSIS_hpbl_1Day  REANALYSIS_shum_2m_1Day  \
# count             21430.000000          21430.000000             21430.000000
# mean                  0.749978              0.189104                 0.223402
# std                   0.355703              0.120254                 0.144256
# min                   0.000015              0.000000                 0.005216
# 25%                   0.515035              0.099403                 0.136044
# 50%                   0.999907              0.158290                 0.184849
# 75%                   0.999950              0.243825                 0.259678
# max                   0.999992              0.851503                 0.989233
#
#        REANALYSIS_prate_1Day  REANALYSIS_vis_1Day  \
# count           21430.000000         21430.000000
# mean                0.007321             0.902469
# std                 0.027727             0.179929
# min                 0.001043             0.000000
# 25%                 0.001649             0.887742
# 50%                 0.002711             0.999903
# 75%                 0.003374             0.999953
# max                 0.759784             0.999971
#
#        REANALYSIS_air_sfc_DailyMin  REANALYSIS_air_sfc_DailyMean  \
# count                 21430.000000                  21430.000000
# mean                      0.615570                      0.664354
# std                       0.100219                      0.107091
# min                       0.048752                      0.100900
# 25%                       0.565310                      0.599212
# 50%                       0.603114                      0.648933
# 75%                       0.652895                      0.721264
# max                       1.000000                      1.000000
#
#        REANALYSIS_air_sfc_DailyMax   MOD04L2_550       MOD09A1  \
# count                 21430.000000  21430.000000  21430.000000
# mean                      0.628955      0.041499      0.090887
# std                       0.113938      0.048464      0.093709
# min                       0.094291     -0.042382     -0.063968
# 25%                       0.545001      0.015156      0.047785
# 50%                       0.611844      0.033015      0.064721
# 75%                       0.712256      0.056957      0.087747
# max                       0.975416      1.000000      0.775241
#
#        MOD11A1_LST_Day_1km_Nearest4  MOD11A1_LST_Night_1km_Nearest4  \
# count                  21430.000000                    21430.000000
# mean                       0.499216                        0.521399
# std                        0.118532                        0.102857
# min                        0.012783                        0.128885
# 25%                        0.419464                        0.453920
# 50%                        0.485235                        0.504843
# 75%                        0.578231                        0.578585
# max                        0.927289                        0.951899
#
#        MOD11A1_Clear_day_cov_Nearest4  MOD11A1_Clear_night_cov_Nearest4  \
# count                    21430.000000                      21430.000000
# mean                         0.476452                          0.609251
# std                          0.140082                          0.121883
# min                          0.000000                          0.001787
# 25%                          0.429254                          0.565248
# 50%                          0.442823                          0.592465
# 75%                          0.492973                          0.639284
# max                          0.916141                          0.862029
#
#        MOD13A2_Nearest4  Nearby_Peak2_NO2  Nearby_Peak2_PM25  \
# count      21430.000000      2.143000e+04       21430.000000
# mean           0.410519      2.375161e-01           0.057904
# std            0.145777      1.161479e-01           0.041881
# min            0.028727      9.942296e-18           0.000000
# 25%            0.299963      1.574313e-01           0.031287
# 50%            0.403902      2.286516e-01           0.050125
# 75%            0.515663      3.064058e-01           0.072477
# max            1.000000      1.000000e+00           0.540255
#
#        Nearby_Peak2_Ozone  Nearby_Peak2Lag1_NO2  Nearby_Peak2Lag1_PM25  \
# count        2.143000e+04          2.143000e+04           21430.000000
# mean         4.233251e-01          2.264321e-01               0.057527
# std          1.186567e-01          1.143712e-01               0.044532
# min          1.519358e-13          9.942296e-18               0.000000
# 25%          3.548387e-01          1.467877e-01               0.030355
# 50%          4.354839e-01          2.164043e-01               0.048495
# 75%          5.000184e-01          2.945194e-01               0.071032
# max          9.807737e-01          9.711443e-01               0.540255
#
#        Nearby_Peak2Lag1_Ozone  Nearby_Peak2Lag3_NO2  Nearby_Peak2Lag3_PM25  \
# count            2.143000e+04          2.143000e+04           21430.000000
# mean             4.321967e-01          2.132295e-01               0.056875
# std              1.152411e-01          1.153125e-01               0.049275
# min              1.519358e-13          9.942296e-18               0.000000
# 25%              3.709677e-01          1.283582e-01               0.028403
# 50%              4.457838e-01          2.009979e-01               0.045042
# 75%              5.070821e-01          2.815526e-01               0.069472
# max              9.807737e-01          9.711443e-01               0.540255
#
#        Nearby_Peak2Lag3_Ozone  Nearby_Peak2_MaxTemperature  \
# count            2.143000e+04                 2.143000e+04
# mean             4.447841e-01                 5.420153e-01
# std              1.087855e-01                 1.165917e-01
# min              1.519358e-13                 3.407693e-09
# 25%              3.885929e-01                 4.680537e-01
# 50%              4.581645e-01                 5.395405e-01
# 75%              5.157927e-01                 6.142418e-01
# max              9.807737e-01                 1.000000e+00
#
#        Nearby_Peak2_MeanTemperature  Nearby_Peak2_MinTemperature  \
# count                  21430.000000                 21430.000000
# mean                       0.522446                     0.547772
# std                        0.114012                     0.111644
# min                        0.055045                     0.000000
# 25%                        0.452718                     0.488521
# 50%                        0.519937                     0.554236
# 75%                        0.590948                     0.616187
# max                        0.990856                     0.968461
#
#        Nearby_Peak2Lag1_MaxTemperature  Nearby_Peak2Lag1_MeanTemperature  \
# count                     2.143000e+04                      21430.000000
# mean                      5.383795e-01                          0.524212
# std                       1.188159e-01                          0.116042
# min                       3.364467e-09                          0.055223
# 25%                       4.603584e-01                          0.449833
# 50%                       5.364010e-01                          0.523003
# 75%                       6.138813e-01                          0.594724
# max                       1.000000e+00                          0.990909
#
#        Nearby_Peak2Lag1_MinTemperature  Nearby_Peak2Lag3_MaxTemperature  \
# count                     21430.000000                     2.143000e+04
# mean                          0.548061                     5.424680e-01
# std                           0.112624                     1.208452e-01
# min                           0.000000                     3.349204e-09
# 25%                           0.486258                     4.623851e-01
# 50%                           0.557665                     5.469694e-01
# 75%                           0.616853                     6.164563e-01
# max                           0.968555                     1.000000e+00
#
#        Nearby_Peak2Lag3_MeanTemperature  Nearby_Peak2Lag3_MinTemperature  \
# count                      21430.000000                     21430.000000
# mean                           0.526545                         0.547971
# std                            0.116960                         0.111850
# min                            0.075414                         0.000000
# 25%                            0.448157                         0.487942
# 50%                            0.530878                         0.563008
# 75%                            0.598456                         0.616801
# max                            0.990877                         0.968555
#
#        OMAEROe_UVAerosolIndex_Mean  OMAEROe_VISAerosolIndex_Mean  \
# count                 21430.000000                  21430.000000
# mean                      0.483122                      0.482761
# std                       0.116819                      0.128938
# min                       0.082772                      0.036852
# 25%                       0.415303                      0.390289
# 50%                       0.482194                      0.469600
# 75%                       0.546198                      0.574722
# max                       1.000000                      0.930430
#
#        OMAERUVd_UVAerosolIndex_Mean  \
# count                  21430.000000
# mean                       0.251356
# std                        0.127908
# min                        0.001917
# 25%                        0.165888
# 50%                        0.234168
# 75%                        0.312020
# max                        1.000000
#
#        OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean        OMO3PR  \
# count                                    21430.000000  21430.000000
# mean                                         0.385198      0.610306
# std                                          0.326937      0.102543
# min                                          0.000000      0.046508
# 25%                                          0.000000      0.539716
# 50%                                          0.537543      0.608493
# 75%                                          0.657854      0.682439
# max                                          0.905352      1.000000
#
#        OMSO2e_ColumnAmountSO2_PBL_Mean  OMTO3e_ColumnAmountO3  \
# count                     21430.000000           21430.000000
# mean                          0.449479               0.314810
# std                           0.063076               0.122034
# min                           0.000000               0.041674
# 25%                           0.427028               0.228167
# 50%                           0.447090               0.293158
# 75%                           0.467619               0.380086
# max                           0.898116               0.902946
#
#        OMUVBd_UVindex_Mean
# count         21430.000000
# mean              0.213418
# std               0.119382
# min              -0.050301
# 25%               0.128367
# 50%               0.192579
# 75%               0.275050
# max               0.927911

# %%
#correlation matrix
corr_matrix = data.corr()
corr_matrix
# Out:
#                                                         site          date  \
# site                                            1.000000e+00  9.306981e-18
# date                                            9.306981e-18  1.000000e+00
# GFEDFireCarbon                                  2.673643e-03  3.014170e-03
# USElevation_dsc10000                            8.794204e-02 -8.432681e-19
# USElevation_max100                              8.761629e-02  1.089337e-18
# USElevation_max10000                            8.763116e-02 -2.509845e-18
# USElevation_mea100                              8.752683e-02 -2.296789e-18
# USElevation_mea10000                            8.793771e-02 -1.855492e-18
# USElevation_med100                              8.749046e-02  1.820926e-18
# USElevation_med10000                            8.794447e-02 -1.644611e-18
# USElevation_min100                              8.766894e-02  1.377000e-18
# USElevation_min10000                            8.820624e-02  3.302675e-18
# USElevation_std100                              2.808909e-02 -6.958620e-19
# USElevation_std10000                            2.179512e-02  6.473298e-19
# USElevation_bln100                              8.761778e-02 -9.012815e-19
# USElevation_bln10000                            8.776210e-02 -3.919429e-18
# NLCD_Barren100                                  5.083715e-03 -2.278133e-19
# NLCD_Barren10000                               -1.383457e-02 -8.082966e-19
# NLCD_Developed100                               6.505075e-03  4.022074e-19
# NLCD_Developed10000                            -9.150961e-02 -7.879294e-19
# NLCD_Herbaceous100                             -1.772123e-02  3.762303e-19
# NLCD_Herbaceous10000                            6.366763e-03 -1.197346e-19
# NLCD_Planted100                                 9.057823e-03 -3.798474e-19
# NLCD_Planted10000                               2.647577e-02 -2.382106e-19
# NLCD_Shrubland100                               1.350041e-02  1.290338e-18
# NLCD_Shrubland10000                             3.869145e-02 -3.044235e-18
# NLCD_Water100                                   1.209065e-02 -3.569733e-19
# NLCD_Water10000                                 3.979790e-02 -9.060375e-19
# NLCD_Wetlands100                                3.757504e-02  2.568055e-19
# NLCD_Wetlands10000                              3.706112e-02  1.966407e-19
# NLCD_Impervious100                              4.689444e-03  3.989868e-19
# NLCD_Impervious10000                           -8.859335e-02  3.098163e-18
# RoadDensity_primaryroads1000                   -5.294826e-02 -5.179466e-20
# RoadDensity_primaryroads10000                  -2.434844e-02  7.306958e-19
# Business_Restaurant1000                         2.751404e-02 -2.292773e-19
# PM25_Region                                     2.889908e-02  2.397599e-19
# Ozone_Region                                   -2.859113e-02 -8.022783e-19
# NO2_Region                                     -2.830364e-03 -2.319690e-19
# MAIACUS_Optical_Depth_047_Aqua_Nearest4         6.835699e-02  7.784475e-02
# MAIACUS_Optical_Depth_055_Aqua_Nearest4         7.059988e-02  7.943549e-02
# MAIACUS_Optical_Depth_047_Terra_Nearest4        4.087138e-02  4.724760e-02
# MAIACUS_Optical_Depth_055_Terra_Nearest4        4.365800e-02  4.464017e-02
# MAIACUS_cosVZA_Aqua_Nearest                     1.113654e-02  1.212266e-02
# MAIACUS_cosVZA_Terra_Nearest                    3.772483e-03  9.930658e-04
# REANALYSIS_hpbl_DailyMax                        3.698984e-02 -3.285290e-01
# REANALYSIS_shum_2m_DailyMax                    -2.185062e-02  9.411787e-02
# REANALYSIS_windspeed_10m_DailyMax               1.494433e-02 -3.050617e-01
# REANALYSIS_prate_DailyMax                       5.379096e-02  9.541004e-02
# REANALYSIS_vis_DailyMax                        -1.229565e-02  7.921595e-03
# REANALYSIS_apcp_DailyMean                       5.852079e-02  9.664906e-02
# REANALYSIS_dlwrf_DailyMean                     -1.670677e-02  1.399595e-01
# REANALYSIS_dswrf_DailyMean                     -1.203420e-01  1.400329e-02
# REANALYSIS_evap_DailyMean                      -6.595285e-03 -1.761125e-01
# REANALYSIS_hpbl_DailyMean                       5.326620e-02 -3.598880e-01
# REANALYSIS_gflux_DailyMean                      1.212799e-02 -2.913950e-01
# REANALYSIS_lhtfl_DailyMean                      6.594634e-03  1.761146e-01
# REANALYSIS_shtfl_DailyMean                      6.038064e-02  2.908410e-02
# REANALYSIS_shum_2m_DailyMean                   -2.798785e-02  1.525014e-01
# REANALYSIS_snowc_DailyMean                      3.871001e-02  2.108687e-02
# REANALYSIS_soilm_DailyMean                      2.894127e-02 -6.825554e-03
# REANALYSIS_tcdc_DailyMean                       7.640078e-02  2.277578e-02
# REANALYSIS_windspeed_10m_DailyMean              2.454467e-03 -2.659972e-01
# REANALYSIS_weasd_DailyMean                      3.705465e-02 -4.582097e-03
# REANALYSIS_prate_DailyMean                      5.671577e-02  9.245921e-02
# REANALYSIS_vis_DailyMean                       -6.625193e-02 -3.500319e-02
# REANALYSIS_hpbl_DailyMin                        4.570095e-02 -3.138847e-01
# REANALYSIS_shum_2m_DailyMin                    -2.943188e-02  2.087635e-01
# REANALYSIS_windspeed_10m_DailyMin              -2.221162e-02 -1.629384e-01
# REANALYSIS_prate_DailyMin                       1.946507e-02  5.872412e-02
# REANALYSIS_vis_DailyMin                        -6.881713e-02 -3.201021e-02
# REANALYSIS_hpbl_1Day                            5.490988e-02 -2.796056e-01
# REANALYSIS_shum_2m_1Day                        -3.254732e-02  3.834082e-02
# REANALYSIS_prate_1Day                           5.674619e-02  6.270490e-02
# REANALYSIS_vis_1Day                            -6.074222e-02  1.021484e-01
# REANALYSIS_air_sfc_DailyMin                    -6.332817e-02  9.059177e-02
# REANALYSIS_air_sfc_DailyMean                   -9.774312e-02  9.332847e-02
# REANALYSIS_air_sfc_DailyMax                    -1.337797e-01  1.155609e-01
# MOD04L2_550                                     8.975445e-03  5.401408e-02
# MOD09A1                                         5.257367e-02  1.138934e-02
# MOD11A1_LST_Day_1km_Nearest4                   -1.327706e-01  1.281941e-01
# MOD11A1_LST_Night_1km_Nearest4                 -9.170074e-02  4.011134e-02
# MOD11A1_Clear_day_cov_Nearest4                 -6.519258e-03  5.497804e-03
# MOD11A1_Clear_night_cov_Nearest4               -1.595684e-02  6.170429e-03
# MOD13A2_Nearest4                               -2.177810e-02 -6.600350e-02
# Nearby_Peak2_NO2                               -9.935011e-02  2.255575e-01
# Nearby_Peak2_PM25                              -1.120221e-01  1.183255e-01
# Nearby_Peak2_Ozone                              3.542347e-02 -1.822861e-01
# Nearby_Peak2Lag1_NO2                           -9.862267e-02  2.591157e-01
# Nearby_Peak2Lag1_PM25                          -1.147432e-01  8.345314e-02
# Nearby_Peak2Lag1_Ozone                          3.743016e-02 -1.674796e-01
# Nearby_Peak2Lag3_NO2                           -8.868300e-02  3.716853e-01
# Nearby_Peak2Lag3_PM25                          -1.422428e-01  1.818439e-02
# Nearby_Peak2Lag3_Ozone                          5.597781e-02 -1.415437e-01
# Nearby_Peak2_MaxTemperature                    -1.073736e-01  9.364379e-02
# Nearby_Peak2_MeanTemperature                   -8.295019e-02  1.202018e-01
# Nearby_Peak2_MinTemperature                    -6.240200e-02  1.706014e-01
# Nearby_Peak2Lag1_MaxTemperature                -1.085266e-01  4.354759e-02
# Nearby_Peak2Lag1_MeanTemperature               -8.237556e-02  7.189009e-02
# Nearby_Peak2Lag1_MinTemperature                -6.118647e-02  1.146578e-01
# Nearby_Peak2Lag3_MaxTemperature                -1.158839e-01  1.945753e-02
# Nearby_Peak2Lag3_MeanTemperature               -8.640197e-02  6.554292e-03
# Nearby_Peak2Lag3_MinTemperature                -6.552142e-02  4.854156e-03
# OMAEROe_UVAerosolIndex_Mean                    -1.972413e-02  2.040920e-02
# OMAEROe_VISAerosolIndex_Mean                    9.428216e-02 -8.604183e-03
# OMAERUVd_UVAerosolIndex_Mean                    1.829879e-04 -6.746007e-02
# OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean -3.688403e-02  1.865181e-03
# OMO3PR                                         -3.505397e-03  4.406392e-01
# OMSO2e_ColumnAmountSO2_PBL_Mean                -2.395142e-02  6.176551e-02
# OMTO3e_ColumnAmountO3                           6.367889e-02 -2.599535e-01
# OMUVBd_UVindex_Mean                            -8.316842e-02  1.788111e-02
#
#                                                 GFEDFireCarbon  \
# site                                                  0.002674
# date                                                  0.003014
# GFEDFireCarbon                                        1.000000
# USElevation_dsc10000                                 -0.041706
# USElevation_max100                                   -0.041163
# USElevation_max10000                                 -0.041885
# USElevation_mea100                                   -0.041014
# USElevation_mea10000                                 -0.041703
# USElevation_med100                                   -0.041022
# USElevation_med10000                                 -0.041699
# USElevation_min100                                   -0.040865
# USElevation_min10000                                 -0.041533
# USElevation_std100                                   -0.021222
# USElevation_std10000                                 -0.033312
# USElevation_bln100                                   -0.041047
# USElevation_bln10000                                 -0.041666
# NLCD_Barren100                                        0.000169
# NLCD_Barren10000                                     -0.006875
# NLCD_Developed100                                     0.001373
# NLCD_Developed10000                                  -0.027120
# NLCD_Herbaceous100                                   -0.010112
# NLCD_Herbaceous10000                                 -0.022491
# NLCD_Planted100                                      -0.004049
# NLCD_Planted10000                                     0.048871
# NLCD_Shrubland100                                    -0.012110
# NLCD_Shrubland10000                                  -0.022141
# NLCD_Water100                                        -0.003567
# NLCD_Water10000                                      -0.006299
# NLCD_Wetlands100                                     -0.001590
# NLCD_Wetlands10000                                    0.110227
# NLCD_Impervious100                                    0.005351
# NLCD_Impervious10000                                 -0.027761
# RoadDensity_primaryroads1000                         -0.022797
# RoadDensity_primaryroads10000                        -0.038810
# Business_Restaurant1000                              -0.013447
# PM25_Region                                           0.006991
# Ozone_Region                                         -0.028853
# NO2_Region                                           -0.013592
# MAIACUS_Optical_Depth_047_Aqua_Nearest4               0.011585
# MAIACUS_Optical_Depth_055_Aqua_Nearest4               0.008581
# MAIACUS_Optical_Depth_047_Terra_Nearest4              0.059916
# MAIACUS_Optical_Depth_055_Terra_Nearest4              0.055433
# MAIACUS_cosVZA_Aqua_Nearest                          -0.009821
# MAIACUS_cosVZA_Terra_Nearest                         -0.008887
# REANALYSIS_hpbl_DailyMax                              0.002751
# REANALYSIS_shum_2m_DailyMax                           0.109354
# REANALYSIS_windspeed_10m_DailyMax                    -0.037043
# REANALYSIS_prate_DailyMax                             0.009243
# REANALYSIS_vis_DailyMax                               0.008670
# REANALYSIS_apcp_DailyMean                             0.002030
# REANALYSIS_dlwrf_DailyMean                            0.080289
# REANALYSIS_dswrf_DailyMean                            0.074360
# REANALYSIS_evap_DailyMean                             0.077037
# REANALYSIS_hpbl_DailyMean                            -0.020562
# REANALYSIS_gflux_DailyMean                            0.011414
# REANALYSIS_lhtfl_DailyMean                           -0.077036
# REANALYSIS_shtfl_DailyMean                           -0.075649
# REANALYSIS_shum_2m_DailyMean                          0.108918
# REANALYSIS_snowc_DailyMean                           -0.013360
# REANALYSIS_soilm_DailyMean                           -0.132784
# REANALYSIS_tcdc_DailyMean                            -0.014832
# REANALYSIS_windspeed_10m_DailyMean                   -0.025779
# REANALYSIS_weasd_DailyMean                           -0.014087
# REANALYSIS_prate_DailyMean                            0.004333
# REANALYSIS_vis_DailyMean                              0.001030
# REANALYSIS_hpbl_DailyMin                             -0.028388
# REANALYSIS_shum_2m_DailyMin                           0.104792
# REANALYSIS_windspeed_10m_DailyMin                     0.001652
# REANALYSIS_prate_DailyMin                            -0.003162
# REANALYSIS_vis_DailyMin                              -0.011641
# REANALYSIS_hpbl_1Day                                 -0.022907
# REANALYSIS_shum_2m_1Day                               0.105329
# REANALYSIS_prate_1Day                                -0.000806
# REANALYSIS_vis_1Day                                   0.005633
# REANALYSIS_air_sfc_DailyMin                           0.094522
# REANALYSIS_air_sfc_DailyMean                          0.101895
# REANALYSIS_air_sfc_DailyMax                           0.093381
# MOD04L2_550                                           0.003530
# MOD09A1                                              -0.026966
# MOD11A1_LST_Day_1km_Nearest4                          0.092453
# MOD11A1_LST_Night_1km_Nearest4                        0.085450
# MOD11A1_Clear_day_cov_Nearest4                        0.019848
# MOD11A1_Clear_night_cov_Nearest4                      0.009988
# MOD13A2_Nearest4                                      0.062589
# Nearby_Peak2_NO2                                      0.012475
# Nearby_Peak2_PM25                                     0.003734
# Nearby_Peak2_Ozone                                    0.073054
# Nearby_Peak2Lag1_NO2                                  0.015944
# Nearby_Peak2Lag1_PM25                                 0.006789
# Nearby_Peak2Lag1_Ozone                                0.074312
# Nearby_Peak2Lag3_NO2                                  0.019590
# Nearby_Peak2Lag3_PM25                                 0.006273
# Nearby_Peak2Lag3_Ozone                                0.069246
# Nearby_Peak2_MaxTemperature                           0.062403
# Nearby_Peak2_MeanTemperature                          0.067911
# Nearby_Peak2_MinTemperature                           0.060109
# Nearby_Peak2Lag1_MaxTemperature                       0.061065
# Nearby_Peak2Lag1_MeanTemperature                      0.066214
# Nearby_Peak2Lag1_MinTemperature                       0.058680
# Nearby_Peak2Lag3_MaxTemperature                       0.057968
# Nearby_Peak2Lag3_MeanTemperature                      0.063790
# Nearby_Peak2Lag3_MinTemperature                       0.056295
# OMAEROe_UVAerosolIndex_Mean                          -0.013235
# OMAEROe_VISAerosolIndex_Mean                         -0.029988
# OMAERUVd_UVAerosolIndex_Mean                         -0.034923
# OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean        0.032428
# OMO3PR                                                0.013331
# OMSO2e_ColumnAmountSO2_PBL_Mean                      -0.001807
# OMTO3e_ColumnAmountO3                                -0.077110
# OMUVBd_UVindex_Mean                                   0.134947
#
#                                                 USElevation_dsc10000  \
# site                                                    8.794204e-02
# date                                                   -8.432681e-19
# GFEDFireCarbon                                         -4.170645e-02
# USElevation_dsc10000                                    1.000000e+00
# USElevation_max100                                      9.920198e-01
# USElevation_max10000                                    9.999216e-01
# USElevation_mea100                                      9.922379e-01
# USElevation_mea10000                                    1.000000e+00
# USElevation_med100                                      9.921890e-01
# USElevation_med10000                                    9.999999e-01
# USElevation_min100                                      9.925404e-01
# USElevation_min10000                                    9.999249e-01
# USElevation_std100                                      2.401336e-01
# USElevation_std10000                                    4.689874e-01
# USElevation_bln100                                      9.926824e-01
# USElevation_bln10000                                    9.999897e-01
# NLCD_Barren100                                          1.780582e-02
# NLCD_Barren10000                                        1.625452e-01
# NLCD_Developed100                                      -1.905129e-01
# NLCD_Developed10000                                    -3.219584e-01
# NLCD_Herbaceous100                                      1.521643e-01
# NLCD_Herbaceous10000                                    3.036955e-01
# NLCD_Planted100                                        -7.098099e-02
# NLCD_Planted10000                                      -4.793754e-02
# NLCD_Shrubland100                                       2.777862e-01
# NLCD_Shrubland10000                                     5.126056e-01
# NLCD_Water100                                           4.208018e-03
# NLCD_Water10000                                        -2.161344e-01
# NLCD_Wetlands100                                        2.074960e-02
# NLCD_Wetlands10000                                     -1.844060e-01
# NLCD_Impervious100                                     -1.898024e-01
# NLCD_Impervious10000                                   -3.101541e-01
# RoadDensity_primaryroads1000                           -9.032589e-02
# RoadDensity_primaryroads10000                          -2.425332e-01
# Business_Restaurant1000                                -8.532591e-02
# PM25_Region                                            -6.214075e-02
# Ozone_Region                                            1.860361e-02
# NO2_Region                                             -6.490487e-02
# MAIACUS_Optical_Depth_047_Aqua_Nearest4                 3.034110e-02
# MAIACUS_Optical_Depth_055_Aqua_Nearest4                 6.551047e-02
# MAIACUS_Optical_Depth_047_Terra_Nearest4                4.509530e-02
# MAIACUS_Optical_Depth_055_Terra_Nearest4                8.653295e-02
# MAIACUS_cosVZA_Aqua_Nearest                            -7.923389e-03
# MAIACUS_cosVZA_Terra_Nearest                            2.736915e-02
# REANALYSIS_hpbl_DailyMax                                6.316961e-02
# REANALYSIS_shum_2m_DailyMax                            -3.074621e-01
# REANALYSIS_windspeed_10m_DailyMax                      -7.526544e-02
# REANALYSIS_prate_DailyMax                              -6.456236e-02
# REANALYSIS_vis_DailyMax                                 3.588777e-02
# REANALYSIS_apcp_DailyMean                              -6.209872e-02
# REANALYSIS_dlwrf_DailyMean                             -4.622940e-01
# REANALYSIS_dswrf_DailyMean                              4.836016e-02
# REANALYSIS_evap_DailyMean                              -1.888803e-01
# REANALYSIS_hpbl_DailyMean                               1.039642e-01
# REANALYSIS_gflux_DailyMean                             -6.487700e-02
# REANALYSIS_lhtfl_DailyMean                              1.888748e-01
# REANALYSIS_shtfl_DailyMean                              3.950989e-01
# REANALYSIS_shum_2m_DailyMean                           -3.034243e-01
# REANALYSIS_snowc_DailyMean                              3.542800e-01
# REANALYSIS_soilm_DailyMean                             -1.457768e-01
# REANALYSIS_tcdc_DailyMean                              -1.891413e-01
# REANALYSIS_windspeed_10m_DailyMean                     -8.448919e-02
# REANALYSIS_weasd_DailyMean                              3.093488e-01
# REANALYSIS_prate_DailyMean                             -5.824042e-02
# REANALYSIS_vis_DailyMean                                1.050663e-01
# REANALYSIS_hpbl_DailyMin                                1.581246e-01
# REANALYSIS_shum_2m_DailyMin                            -2.851184e-01
# REANALYSIS_windspeed_10m_DailyMin                      -2.284926e-02
# REANALYSIS_prate_DailyMin                              -2.255352e-02
# REANALYSIS_vis_DailyMin                                 1.289804e-01
# REANALYSIS_hpbl_1Day                                    1.664261e-01
# REANALYSIS_shum_2m_1Day                                -3.117660e-01
# REANALYSIS_prate_1Day                                  -3.507319e-02
# REANALYSIS_vis_1Day                                     8.801567e-02
# REANALYSIS_air_sfc_DailyMin                            -3.946948e-01
# REANALYSIS_air_sfc_DailyMean                           -3.659390e-01
# REANALYSIS_air_sfc_DailyMax                            -2.207088e-01
# MOD04L2_550                                            -2.008883e-01
# MOD09A1                                                 3.295638e-01
# MOD11A1_LST_Day_1km_Nearest4                           -2.116973e-01
# MOD11A1_LST_Night_1km_Nearest4                         -3.651683e-01
# MOD11A1_Clear_day_cov_Nearest4                          1.153191e-02
# MOD11A1_Clear_night_cov_Nearest4                        6.826805e-02
# MOD13A2_Nearest4                                       -3.284604e-01
# Nearby_Peak2_NO2                                        5.500459e-02
# Nearby_Peak2_PM25                                      -3.714263e-02
# Nearby_Peak2_Ozone                                      2.073296e-01
# Nearby_Peak2Lag1_NO2                                    7.483585e-02
# Nearby_Peak2Lag1_PM25                                  -2.790363e-02
# Nearby_Peak2Lag1_Ozone                                  1.934196e-01
# Nearby_Peak2Lag3_NO2                                    1.099157e-01
# Nearby_Peak2Lag3_PM25                                  -4.741559e-02
# Nearby_Peak2Lag3_Ozone                                  1.691244e-01
# Nearby_Peak2_MaxTemperature                            -1.052736e-01
# Nearby_Peak2_MeanTemperature                           -1.967161e-01
# Nearby_Peak2_MinTemperature                            -2.439742e-01
# Nearby_Peak2Lag1_MaxTemperature                        -1.228867e-01
# Nearby_Peak2Lag1_MeanTemperature                       -2.115157e-01
# Nearby_Peak2Lag1_MinTemperature                        -2.508021e-01
# Nearby_Peak2Lag3_MaxTemperature                        -1.456748e-01
# Nearby_Peak2Lag3_MeanTemperature                       -2.288723e-01
# Nearby_Peak2Lag3_MinTemperature                        -2.614404e-01
# OMAEROe_UVAerosolIndex_Mean                            -9.446053e-02
# OMAEROe_VISAerosolIndex_Mean                            8.266116e-02
# OMAERUVd_UVAerosolIndex_Mean                            3.879891e-02
# OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean         -5.223449e-02
# OMO3PR                                                  1.031172e-01
# OMSO2e_ColumnAmountSO2_PBL_Mean                        -1.305392e-02
# OMTO3e_ColumnAmountO3                                  -5.098503e-02
# OMUVBd_UVindex_Mean                                    -1.727525e-03
#
#                                                 USElevation_max100  \
# site                                                  8.761629e-02
# date                                                  1.089337e-18
# GFEDFireCarbon                                       -4.116310e-02
# USElevation_dsc10000                                  9.920198e-01
# USElevation_max100                                    1.000000e+00
# USElevation_max10000                                  9.917610e-01
# USElevation_mea100                                    9.999223e-01
# USElevation_mea10000                                  9.920179e-01
# USElevation_med100                                    9.999167e-01
# USElevation_med10000                                  9.920216e-01
# USElevation_min100                                    9.997219e-01
# USElevation_min10000                                  9.921032e-01
# USElevation_std100                                    2.732535e-01
# USElevation_std10000                                  4.533086e-01
# USElevation_bln100                                    9.996834e-01
# USElevation_bln10000                                  9.920379e-01
# NLCD_Barren100                                        2.516593e-02
# NLCD_Barren10000                                      1.558693e-01
# NLCD_Developed100                                    -2.065553e-01
# NLCD_Developed10000                                  -3.210794e-01
# NLCD_Herbaceous100                                    1.595474e-01
# NLCD_Herbaceous10000                                  2.995734e-01
# NLCD_Planted100                                      -7.008778e-02
# NLCD_Planted10000                                    -4.583946e-02
# NLCD_Shrubland100                                     2.769888e-01
# NLCD_Shrubland10000                                   4.993807e-01
# NLCD_Water100                                         5.605540e-04
# NLCD_Water10000                                      -2.134080e-01
# NLCD_Wetlands100                                      1.901365e-02
# NLCD_Wetlands10000                                   -1.801573e-01
# NLCD_Impervious100                                   -2.051798e-01
# NLCD_Impervious10000                                 -3.094704e-01
# RoadDensity_primaryroads1000                         -9.302924e-02
# RoadDensity_primaryroads10000                        -2.411261e-01
# Business_Restaurant1000                              -8.600720e-02
# PM25_Region                                          -5.577182e-02
# Ozone_Region                                          1.793829e-02
# NO2_Region                                           -6.792818e-02
# MAIACUS_Optical_Depth_047_Aqua_Nearest4               3.178559e-02
# MAIACUS_Optical_Depth_055_Aqua_Nearest4               6.602689e-02
# MAIACUS_Optical_Depth_047_Terra_Nearest4              4.246998e-02
# MAIACUS_Optical_Depth_055_Terra_Nearest4              8.266135e-02
# MAIACUS_cosVZA_Aqua_Nearest                          -8.847398e-03
# MAIACUS_cosVZA_Terra_Nearest                          2.755936e-02
# REANALYSIS_hpbl_DailyMax                              6.520204e-02
# REANALYSIS_shum_2m_DailyMax                          -3.015781e-01
# REANALYSIS_windspeed_10m_DailyMax                    -6.754320e-02
# REANALYSIS_prate_DailyMax                            -6.172080e-02
# REANALYSIS_vis_DailyMax                               3.450980e-02
# REANALYSIS_apcp_DailyMean                            -5.869309e-02
# REANALYSIS_dlwrf_DailyMean                           -4.559401e-01
# REANALYSIS_dswrf_DailyMean                            5.178887e-02
# REANALYSIS_evap_DailyMean                            -1.844207e-01
# REANALYSIS_hpbl_DailyMean                             1.046860e-01
# REANALYSIS_gflux_DailyMean                           -6.299275e-02
# REANALYSIS_lhtfl_DailyMean                            1.844158e-01
# REANALYSIS_shtfl_DailyMean                            3.838299e-01
# REANALYSIS_shum_2m_DailyMean                         -2.977867e-01
# REANALYSIS_snowc_DailyMean                            3.493712e-01
# REANALYSIS_soilm_DailyMean                           -1.470238e-01
# REANALYSIS_tcdc_DailyMean                            -1.893831e-01
# REANALYSIS_windspeed_10m_DailyMean                   -7.664765e-02
# REANALYSIS_weasd_DailyMean                            3.029650e-01
# REANALYSIS_prate_DailyMean                           -5.435686e-02
# REANALYSIS_vis_DailyMean                              1.037778e-01
# REANALYSIS_hpbl_DailyMin                              1.575645e-01
# REANALYSIS_shum_2m_DailyMin                          -2.796752e-01
# REANALYSIS_windspeed_10m_DailyMin                    -2.101132e-02
# REANALYSIS_prate_DailyMin                            -1.807715e-02
# REANALYSIS_vis_DailyMin                               1.282365e-01
# REANALYSIS_hpbl_1Day                                  1.656283e-01
# REANALYSIS_shum_2m_1Day                              -3.060163e-01
# REANALYSIS_prate_1Day                                -3.135768e-02
# REANALYSIS_vis_1Day                                   8.683987e-02
# REANALYSIS_air_sfc_DailyMin                          -3.880843e-01
# REANALYSIS_air_sfc_DailyMean                         -3.599094e-01
# REANALYSIS_air_sfc_DailyMax                          -2.173475e-01
# MOD04L2_550                                          -2.012691e-01
# MOD09A1                                               3.295993e-01
# MOD11A1_LST_Day_1km_Nearest4                         -2.124764e-01
# MOD11A1_LST_Night_1km_Nearest4                       -3.610054e-01
# MOD11A1_Clear_day_cov_Nearest4                        1.296807e-02
# MOD11A1_Clear_night_cov_Nearest4                      6.891193e-02
# MOD13A2_Nearest4                                     -3.218047e-01
# Nearby_Peak2_NO2                                      4.948797e-02
# Nearby_Peak2_PM25                                    -4.544195e-02
# Nearby_Peak2_Ozone                                    2.091135e-01
# Nearby_Peak2Lag1_NO2                                  6.917244e-02
# Nearby_Peak2Lag1_PM25                                -3.600156e-02
# Nearby_Peak2Lag1_Ozone                                1.959706e-01
# Nearby_Peak2Lag3_NO2                                  1.041558e-01
# Nearby_Peak2Lag3_PM25                                -5.384488e-02
# Nearby_Peak2Lag3_Ozone                                1.733509e-01
# Nearby_Peak2_MaxTemperature                          -1.079852e-01
# Nearby_Peak2_MeanTemperature                         -1.968619e-01
# Nearby_Peak2_MinTemperature                          -2.435958e-01
# Nearby_Peak2Lag1_MaxTemperature                      -1.257165e-01
# Nearby_Peak2Lag1_MeanTemperature                     -2.118287e-01
# Nearby_Peak2Lag1_MinTemperature                      -2.509387e-01
# Nearby_Peak2Lag3_MaxTemperature                      -1.483211e-01
# Nearby_Peak2Lag3_MeanTemperature                     -2.290742e-01
# Nearby_Peak2Lag3_MinTemperature                      -2.620085e-01
# OMAEROe_UVAerosolIndex_Mean                          -9.417823e-02
# OMAEROe_VISAerosolIndex_Mean                          8.166641e-02
# OMAERUVd_UVAerosolIndex_Mean                          3.172600e-02
# OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean       -5.116637e-02
# OMO3PR                                                1.026194e-01
# OMSO2e_ColumnAmountSO2_PBL_Mean                      -1.297104e-02
# OMTO3e_ColumnAmountO3                                -5.144581e-02
# OMUVBd_UVindex_Mean                                   1.022051e-03
#
#                                                 USElevation_max10000  \
# site                                                    8.763116e-02
# date                                                   -2.509845e-18
# GFEDFireCarbon                                         -4.188522e-02
# USElevation_dsc10000                                    9.999216e-01
# USElevation_max100                                      9.917610e-01
# USElevation_max10000                                    1.000000e+00
# USElevation_mea100                                      9.918958e-01
# USElevation_mea10000                                    9.999216e-01
# USElevation_med100                                      9.918478e-01
# USElevation_med10000                                    9.999205e-01
# USElevation_min100                                      9.921132e-01
# USElevation_min10000                                    9.996934e-01
# USElevation_std100                                      2.466972e-01
# USElevation_std10000                                    4.800013e-01
# USElevation_bln100                                      9.923205e-01
# USElevation_bln10000                                    9.998977e-01
# NLCD_Barren100                                          1.790479e-02
# NLCD_Barren10000                                        1.628963e-01
# NLCD_Developed100                                      -1.921758e-01
# NLCD_Developed10000                                    -3.248586e-01
# NLCD_Herbaceous100                                      1.524092e-01
# NLCD_Herbaceous10000                                    3.029778e-01
# NLCD_Planted100                                        -7.103296e-02
# NLCD_Planted10000                                      -5.014454e-02
# NLCD_Shrubland100                                       2.791792e-01
# NLCD_Shrubland10000                                     5.138216e-01
# NLCD_Water100                                           4.371742e-03
# NLCD_Water10000                                        -2.174014e-01
# NLCD_Wetlands100                                        2.022174e-02
# NLCD_Wetlands10000                                     -1.861042e-01
# NLCD_Impervious100                                     -1.914310e-01
# NLCD_Impervious10000                                   -3.130793e-01
# RoadDensity_primaryroads1000                           -9.097428e-02
# RoadDensity_primaryroads10000                          -2.442968e-01
# Business_Restaurant1000                                -8.577720e-02
# PM25_Region                                            -6.146819e-02
# Ozone_Region                                            1.851404e-02
# NO2_Region                                             -6.382587e-02
# MAIACUS_Optical_Depth_047_Aqua_Nearest4                 3.029735e-02
# MAIACUS_Optical_Depth_055_Aqua_Nearest4                 6.544405e-02
# MAIACUS_Optical_Depth_047_Terra_Nearest4                4.543178e-02
# MAIACUS_Optical_Depth_055_Terra_Nearest4                8.684412e-02
# MAIACUS_cosVZA_Aqua_Nearest                            -7.827867e-03
# MAIACUS_cosVZA_Terra_Nearest                            2.730966e-02
# REANALYSIS_hpbl_DailyMax                                6.316273e-02
# REANALYSIS_shum_2m_DailyMax                            -3.066758e-01
# REANALYSIS_windspeed_10m_DailyMax                      -7.555390e-02
# REANALYSIS_prate_DailyMax                              -6.380687e-02
# REANALYSIS_vis_DailyMax                                 3.553637e-02
# REANALYSIS_apcp_DailyMean                              -6.115224e-02
# REANALYSIS_dlwrf_DailyMean                             -4.607663e-01
# REANALYSIS_dswrf_DailyMean                              4.768896e-02
# REANALYSIS_evap_DailyMean                              -1.887585e-01
# REANALYSIS_hpbl_DailyMean                               1.044774e-01
# REANALYSIS_gflux_DailyMean                             -6.539559e-02
# REANALYSIS_lhtfl_DailyMean                              1.887529e-01
# REANALYSIS_shtfl_DailyMean                              3.953403e-01
# REANALYSIS_shum_2m_DailyMean                           -3.027299e-01
# REANALYSIS_snowc_DailyMean                              3.542144e-01
# REANALYSIS_soilm_DailyMean                             -1.437945e-01
# REANALYSIS_tcdc_DailyMean                              -1.874333e-01
# REANALYSIS_windspeed_10m_DailyMean                     -8.443247e-02
# REANALYSIS_weasd_DailyMean                              3.096681e-01
# REANALYSIS_prate_DailyMean                             -5.728710e-02
# REANALYSIS_vis_DailyMean                                1.039314e-01
# REANALYSIS_hpbl_DailyMin                                1.588732e-01
# REANALYSIS_shum_2m_DailyMin                            -2.844480e-01
# REANALYSIS_windspeed_10m_DailyMin                      -2.160953e-02
# REANALYSIS_prate_DailyMin                              -2.168567e-02
# REANALYSIS_vis_DailyMin                                 1.279454e-01
# REANALYSIS_hpbl_1Day                                    1.668173e-01
# REANALYSIS_shum_2m_1Day                                -3.110708e-01
# REANALYSIS_prate_1Day                                  -3.403852e-02
# REANALYSIS_vis_1Day                                     8.715311e-02
# REANALYSIS_air_sfc_DailyMin                            -3.937295e-01
# REANALYSIS_air_sfc_DailyMean                           -3.649583e-01
# REANALYSIS_air_sfc_DailyMax                            -2.199107e-01
# MOD04L2_550                                            -2.008758e-01
# MOD09A1                                                 3.282257e-01
# MOD11A1_LST_Day_1km_Nearest4                           -2.117581e-01
# MOD11A1_LST_Night_1km_Nearest4                         -3.639881e-01
# MOD11A1_Clear_day_cov_Nearest4                          1.130320e-02
# MOD11A1_Clear_night_cov_Nearest4                        6.751099e-02
# MOD13A2_Nearest4                                       -3.240423e-01
# Nearby_Peak2_NO2                                        5.394004e-02
# Nearby_Peak2_PM25                                      -3.601879e-02
# Nearby_Peak2_Ozone                                      2.082589e-01
# Nearby_Peak2Lag1_NO2                                    7.383086e-02
# Nearby_Peak2Lag1_PM25                                  -2.674909e-02
# Nearby_Peak2Lag1_Ozone                                  1.942914e-01
# Nearby_Peak2Lag3_NO2                                    1.090044e-01
# Nearby_Peak2Lag3_PM25                                  -4.638917e-02
# Nearby_Peak2Lag3_Ozone                                  1.700684e-01
# Nearby_Peak2_MaxTemperature                            -1.044852e-01
# Nearby_Peak2_MeanTemperature                           -1.955299e-01
# Nearby_Peak2_MinTemperature                            -2.423757e-01
# Nearby_Peak2Lag1_MaxTemperature                        -1.218886e-01
# Nearby_Peak2Lag1_MeanTemperature                       -2.101912e-01
# Nearby_Peak2Lag1_MinTemperature                        -2.491033e-01
# Nearby_Peak2Lag3_MaxTemperature                        -1.444236e-01
# Nearby_Peak2Lag3_MeanTemperature                       -2.273341e-01
# Nearby_Peak2Lag3_MinTemperature                        -2.595469e-01
# OMAEROe_UVAerosolIndex_Mean                            -9.476455e-02
# OMAEROe_VISAerosolIndex_Mean                            8.311803e-02
# OMAERUVd_UVAerosolIndex_Mean                            3.921869e-02
# OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean         -5.310303e-02
# OMO3PR                                                  1.026451e-01
# OMSO2e_ColumnAmountSO2_PBL_Mean                        -1.327161e-02
# OMTO3e_ColumnAmountO3                                  -5.096627e-02
# OMUVBd_UVindex_Mean                                    -3.109635e-03
#
#                                                 USElevation_mea100  \
# site                                                  8.752683e-02
# date                                                 -2.296789e-18
# GFEDFireCarbon                                       -4.101420e-02
# USElevation_dsc10000                                  9.922379e-01
# USElevation_max100                                    9.999223e-01
# USElevation_max10000                                  9.918958e-01
# USElevation_mea100                                    1.000000e+00
# USElevation_mea10000                                  9.922362e-01
# USElevation_med100                                    9.999985e-01
# USElevation_med10000                                  9.922405e-01
# USElevation_min100                                    9.999222e-01
# USElevation_min10000                                  9.924032e-01
# USElevation_std100                                    2.622557e-01
# USElevation_std10000                                  4.475235e-01
# USElevation_bln100                                    9.997480e-01
# USElevation_bln10000                                  9.922601e-01
# NLCD_Barren100                                        2.510785e-02
# NLCD_Barren10000                                      1.560105e-01
# NLCD_Developed100                                    -2.045941e-01
# NLCD_Developed10000                                  -3.194601e-01
# NLCD_Herbaceous100                                    1.589361e-01
# NLCD_Herbaceous10000                                  3.002964e-01
# NLCD_Planted100                                      -6.999902e-02
# NLCD_Planted10000                                    -4.441706e-02
# NLCD_Shrubland100                                     2.757431e-01
# NLCD_Shrubland10000                                   4.995505e-01
# NLCD_Water100                                         1.934943e-04
# NLCD_Water10000                                      -2.137835e-01
# NLCD_Wetlands100                                      1.956246e-02
# NLCD_Wetlands10000                                   -1.794266e-01
# NLCD_Impervious100                                   -2.032998e-01
# NLCD_Impervious10000                                 -3.078734e-01
# RoadDensity_primaryroads1000                         -9.288637e-02
# RoadDensity_primaryroads10000                        -2.403939e-01
# Business_Restaurant1000                              -8.623824e-02
# PM25_Region                                          -5.609826e-02
# Ozone_Region                                          1.765222e-02
# NO2_Region                                           -6.785304e-02
# MAIACUS_Optical_Depth_047_Aqua_Nearest4               3.172740e-02
# MAIACUS_Optical_Depth_055_Aqua_Nearest4               6.604736e-02
# MAIACUS_Optical_Depth_047_Terra_Nearest4              4.218211e-02
# MAIACUS_Optical_Depth_055_Terra_Nearest4              8.246650e-02
# MAIACUS_cosVZA_Aqua_Nearest                          -8.875046e-03
# MAIACUS_cosVZA_Terra_Nearest                          2.761370e-02
# REANALYSIS_hpbl_DailyMax                              6.509908e-02
# REANALYSIS_shum_2m_DailyMax                          -3.024651e-01
# REANALYSIS_windspeed_10m_DailyMax                    -6.784353e-02
# REANALYSIS_prate_DailyMax                            -6.247547e-02
# REANALYSIS_vis_DailyMax                               3.516463e-02
# REANALYSIS_apcp_DailyMean                            -5.970807e-02
# REANALYSIS_dlwrf_DailyMean                           -4.571781e-01
# REANALYSIS_dswrf_DailyMean                            5.206576e-02
# REANALYSIS_evap_DailyMean                            -1.848126e-01
# REANALYSIS_hpbl_DailyMean                             1.042671e-01
# REANALYSIS_gflux_DailyMean                           -6.287314e-02
# REANALYSIS_lhtfl_DailyMean                            1.848077e-01
# REANALYSIS_shtfl_DailyMean                            3.842724e-01
# REANALYSIS_shum_2m_DailyMean                         -2.986279e-01
# REANALYSIS_snowc_DailyMean                            3.490566e-01
# REANALYSIS_soilm_DailyMean                           -1.486566e-01
# REANALYSIS_tcdc_DailyMean                            -1.905533e-01
# REANALYSIS_windspeed_10m_DailyMean                   -7.720040e-02
# REANALYSIS_weasd_DailyMean                            3.021323e-01
# REANALYSIS_prate_DailyMean                           -5.541339e-02
# REANALYSIS_vis_DailyMean                              1.048895e-01
# REANALYSIS_hpbl_DailyMin                              1.570582e-01
# REANALYSIS_shum_2m_DailyMin                          -2.804801e-01
# REANALYSIS_windspeed_10m_DailyMin                    -2.193758e-02
# REANALYSIS_prate_DailyMin                            -1.938109e-02
# REANALYSIS_vis_DailyMin                               1.290784e-01
# REANALYSIS_hpbl_1Day                                  1.653934e-01
# REANALYSIS_shum_2m_1Day                              -3.068625e-01
# REANALYSIS_prate_1Day                                -3.252533e-02
# REANALYSIS_vis_1Day                                   8.780035e-02
# REANALYSIS_air_sfc_DailyMin                          -3.889777e-01
# REANALYSIS_air_sfc_DailyMean                         -3.606575e-01
# REANALYSIS_air_sfc_DailyMax                          -2.176553e-01
# MOD04L2_550                                          -2.013068e-01
# MOD09A1                                               3.306457e-01
# MOD11A1_LST_Day_1km_Nearest4                         -2.122211e-01
# MOD11A1_LST_Night_1km_Nearest4                       -3.618151e-01
# MOD11A1_Clear_day_cov_Nearest4                        1.302968e-02
# MOD11A1_Clear_night_cov_Nearest4                      6.944692e-02
# MOD13A2_Nearest4                                     -3.249788e-01
# Nearby_Peak2_NO2                                      5.017116e-02
# Nearby_Peak2_PM25                                    -4.560662e-02
# Nearby_Peak2_Ozone                                    2.085886e-01
# Nearby_Peak2Lag1_NO2                                  6.982611e-02
# Nearby_Peak2Lag1_PM25                                -3.619376e-02
# Nearby_Peak2Lag1_Ozone                                1.954317e-01
# Nearby_Peak2Lag3_NO2                                  1.047568e-01
# Nearby_Peak2Lag3_PM25                                -5.403975e-02
# Nearby_Peak2Lag3_Ozone                                1.726832e-01
# Nearby_Peak2_MaxTemperature                          -1.082421e-01
# Nearby_Peak2_MeanTemperature                         -1.974661e-01
# Nearby_Peak2_MinTemperature                          -2.444325e-01
# Nearby_Peak2Lag1_MaxTemperature                      -1.260837e-01
# Nearby_Peak2Lag1_MeanTemperature                     -2.124896e-01
# Nearby_Peak2Lag1_MinTemperature                      -2.517938e-01
# Nearby_Peak2Lag3_MaxTemperature                      -1.488295e-01
# Nearby_Peak2Lag3_MeanTemperature                     -2.298488e-01
# Nearby_Peak2Lag3_MinTemperature                      -2.629428e-01
# OMAEROe_UVAerosolIndex_Mean                          -9.408489e-02
# OMAEROe_VISAerosolIndex_Mean                          8.136098e-02
# OMAERUVd_UVAerosolIndex_Mean                          3.175997e-02
# OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean       -5.060974e-02
# OMO3PR                                                1.030830e-01
# OMSO2e_ColumnAmountSO2_PBL_Mean                      -1.290230e-02
# OMTO3e_ColumnAmountO3                                -5.159123e-02
# OMUVBd_UVindex_Mean                                   1.974476e-03
#
#                                                 USElevation_mea10000  \
# site                                                    8.793771e-02
# date                                                   -1.855492e-18
# GFEDFireCarbon                                         -4.170335e-02
# USElevation_dsc10000                                    1.000000e+00
# USElevation_max100                                      9.920179e-01
# ...
# OMUVBd_UVindex_Mean                                                    0.046575
#
#                                                 OMTO3e_ColumnAmountO3  \
# site                                                         0.063679
# date                                                        -0.259953
# GFEDFireCarbon                                              -0.077110
# USElevation_dsc10000                                        -0.050985
# USElevation_max100                                          -0.051446
# USElevation_max10000                                        -0.050966
# USElevation_mea100                                          -0.051591
# USElevation_mea10000                                        -0.050983
# USElevation_med100                                          -0.051595
# USElevation_med10000                                        -0.050982
# USElevation_min100                                          -0.051704
# USElevation_min10000                                        -0.050992
# USElevation_std100                                           0.003858
# USElevation_std10000                                        -0.018597
# USElevation_bln100                                          -0.051887
# USElevation_bln10000                                        -0.051226
# NLCD_Barren100                                              -0.000482
# NLCD_Barren10000                                            -0.030033
# NLCD_Developed100                                            0.054839
# NLCD_Developed10000                                          0.008334
# NLCD_Herbaceous100                                          -0.010203
# NLCD_Herbaceous10000                                        -0.020540
# NLCD_Planted100                                              0.022476
# NLCD_Planted10000                                            0.040483
# NLCD_Shrubland100                                           -0.056170
# NLCD_Shrubland10000                                         -0.114860
# NLCD_Water100                                                0.016369
# NLCD_Water10000                                              0.069777
# NLCD_Wetlands100                                             0.011392
# NLCD_Wetlands10000                                          -0.071071
# NLCD_Impervious100                                           0.052441
# NLCD_Impervious10000                                         0.005982
# RoadDensity_primaryroads1000                                 0.031285
# RoadDensity_primaryroads10000                                0.044539
# Business_Restaurant1000                                      0.039303
# PM25_Region                                                  0.046741
# Ozone_Region                                                 0.066748
# NO2_Region                                                   0.122324
# MAIACUS_Optical_Depth_047_Aqua_Nearest4                      0.239839
# MAIACUS_Optical_Depth_055_Aqua_Nearest4                      0.237529
# MAIACUS_Optical_Depth_047_Terra_Nearest4                     0.232255
# MAIACUS_Optical_Depth_055_Terra_Nearest4                     0.229368
# MAIACUS_cosVZA_Aqua_Nearest                                  0.022031
# MAIACUS_cosVZA_Terra_Nearest                                 0.083080
# REANALYSIS_hpbl_DailyMax                                     0.361997
# REANALYSIS_shum_2m_DailyMax                                 -0.520130
# REANALYSIS_windspeed_10m_DailyMax                            0.472958
# REANALYSIS_prate_DailyMax                                   -0.019183
# REANALYSIS_vis_DailyMax                                     -0.260818
# REANALYSIS_apcp_DailyMean                                   -0.000811
# REANALYSIS_dlwrf_DailyMean                                  -0.329781
# REANALYSIS_dswrf_DailyMean                                  -0.589115
# REANALYSIS_evap_DailyMean                                   -0.043982
# REANALYSIS_hpbl_DailyMean                                    0.487133
# REANALYSIS_gflux_DailyMean                                   0.485670
# REANALYSIS_lhtfl_DailyMean                                   0.043976
# REANALYSIS_shtfl_DailyMean                                  -0.036663
# REANALYSIS_shum_2m_DailyMean                                -0.518620
# REANALYSIS_snowc_DailyMean                                   0.183814
# REANALYSIS_soilm_DailyMean                                   0.277822
# REANALYSIS_tcdc_DailyMean                                    0.376233
# REANALYSIS_windspeed_10m_DailyMean                           0.437716
# REANALYSIS_weasd_DailyMean                                   0.195240
# REANALYSIS_prate_DailyMean                                   0.002413
# REANALYSIS_vis_DailyMean                                    -0.209764
# REANALYSIS_hpbl_DailyMin                                     0.475177
# REANALYSIS_shum_2m_DailyMin                                 -0.519754
# REANALYSIS_windspeed_10m_DailyMin                            0.207933
# REANALYSIS_prate_DailyMin                                    0.077197
# REANALYSIS_vis_DailyMin                                     -0.159451
# REANALYSIS_hpbl_1Day                                         0.375716
# REANALYSIS_shum_2m_1Day                                     -0.386764
# REANALYSIS_prate_1Day                                        0.049054
# REANALYSIS_vis_1Day                                         -0.279887
# REANALYSIS_air_sfc_DailyMin                                 -0.521301
# REANALYSIS_air_sfc_DailyMean                                -0.617948
# REANALYSIS_air_sfc_DailyMax                                 -0.712560
# MOD04L2_550                                                  0.051379
# MOD09A1                                                      0.229210
# MOD11A1_LST_Day_1km_Nearest4                                -0.715183
# MOD11A1_LST_Night_1km_Nearest4                              -0.587279
# MOD11A1_Clear_day_cov_Nearest4                              -0.165385
# MOD11A1_Clear_night_cov_Nearest4                            -0.120016
# MOD13A2_Nearest4                                            -0.134103
# Nearby_Peak2_NO2                                            -0.301398
# Nearby_Peak2_PM25                                           -0.259279
# Nearby_Peak2_Ozone                                          -0.038525
# Nearby_Peak2Lag1_NO2                                        -0.355171
# Nearby_Peak2Lag1_PM25                                       -0.262959
# Nearby_Peak2Lag1_Ozone                                      -0.023242
# Nearby_Peak2Lag3_NO2                                        -0.283325
# Nearby_Peak2Lag3_PM25                                       -0.157354
# Nearby_Peak2Lag3_Ozone                                      -0.161827
# Nearby_Peak2_MaxTemperature                                 -0.648704
# Nearby_Peak2_MeanTemperature                                -0.615681
# Nearby_Peak2_MinTemperature                                 -0.573888
# Nearby_Peak2Lag1_MaxTemperature                             -0.474376
# Nearby_Peak2Lag1_MeanTemperature                            -0.444210
# Nearby_Peak2Lag1_MinTemperature                             -0.393710
# Nearby_Peak2Lag3_MaxTemperature                             -0.250368
# Nearby_Peak2Lag3_MeanTemperature                            -0.221258
# Nearby_Peak2Lag3_MinTemperature                             -0.154419
# OMAEROe_UVAerosolIndex_Mean                                 -0.017570
# OMAEROe_VISAerosolIndex_Mean                                 0.318188
# OMAERUVd_UVAerosolIndex_Mean                                 0.070776
# OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean              -0.236249
# OMO3PR                                                      -0.408963
# OMSO2e_ColumnAmountSO2_PBL_Mean                             -0.083742
# OMTO3e_ColumnAmountO3                                        1.000000
# OMUVBd_UVindex_Mean                                         -0.643476
#
#                                                 OMUVBd_UVindex_Mean
# site                                                      -0.083168
# date                                                       0.017881
# GFEDFireCarbon                                             0.134947
# USElevation_dsc10000                                      -0.001728
# USElevation_max100                                         0.001022
# USElevation_max10000                                      -0.003110
# USElevation_mea100                                         0.001974
# USElevation_mea10000                                      -0.001731
# USElevation_med100                                         0.001962
# USElevation_med10000                                      -0.001721
# USElevation_min100                                         0.002923
# USElevation_min10000                                      -0.000405
# USElevation_std100                                        -0.082178
# USElevation_std10000                                      -0.103285
# USElevation_bln100                                         0.002493
# USElevation_bln10000                                      -0.001408
# NLCD_Barren100                                            -0.002318
# NLCD_Barren10000                                           0.023757
# NLCD_Developed100                                         -0.094128
# NLCD_Developed10000                                        0.004914
# NLCD_Herbaceous100                                        -0.002557
# NLCD_Herbaceous10000                                      -0.033058
# NLCD_Planted100                                           -0.053122
# NLCD_Planted10000                                         -0.111690
# NLCD_Shrubland100                                          0.083723
# NLCD_Shrubland10000                                        0.142133
# NLCD_Water100                                             -0.014386
# NLCD_Water10000                                           -0.062496
# NLCD_Wetlands100                                           0.000313
# NLCD_Wetlands10000                                         0.110695
# NLCD_Impervious100                                        -0.091695
# NLCD_Impervious10000                                       0.013542
# RoadDensity_primaryroads1000                              -0.031955
# RoadDensity_primaryroads10000                             -0.036679
# Business_Restaurant1000                                   -0.040393
# PM25_Region                                               -0.090891
# Ozone_Region                                              -0.129662
# NO2_Region                                                -0.193914
# MAIACUS_Optical_Depth_047_Aqua_Nearest4                   -0.258787
# MAIACUS_Optical_Depth_055_Aqua_Nearest4                   -0.257085
# MAIACUS_Optical_Depth_047_Terra_Nearest4                  -0.250725
# MAIACUS_Optical_Depth_055_Terra_Nearest4                  -0.248102
# MAIACUS_cosVZA_Aqua_Nearest                               -0.053670
# MAIACUS_cosVZA_Terra_Nearest                              -0.078218
# REANALYSIS_hpbl_DailyMax                                  -0.114200
# REANALYSIS_shum_2m_DailyMax                                0.459054
# REANALYSIS_windspeed_10m_DailyMax                         -0.323157
# REANALYSIS_prate_DailyMax                                 -0.167555
# REANALYSIS_vis_DailyMax                                    0.158277
# REANALYSIS_apcp_DailyMean                                 -0.176763
# REANALYSIS_dlwrf_DailyMean                                 0.199626
# REANALYSIS_dswrf_DailyMean                                 0.793184
# REANALYSIS_evap_DailyMean                                  0.329802
# REANALYSIS_hpbl_DailyMean                                 -0.235809
# REANALYSIS_gflux_DailyMean                                -0.093149
# REANALYSIS_lhtfl_DailyMean                                -0.329801
# REANALYSIS_shtfl_DailyMean                                -0.305088
# REANALYSIS_shum_2m_DailyMean                               0.443608
# REANALYSIS_snowc_DailyMean                                -0.111534
# REANALYSIS_soilm_DailyMean                                -0.380946
# REANALYSIS_tcdc_DailyMean                                 -0.467070
# REANALYSIS_windspeed_10m_DailyMean                        -0.253523
# REANALYSIS_weasd_DailyMean                                -0.131525
# REANALYSIS_prate_DailyMean                                -0.170761
# REANALYSIS_vis_DailyMean                                   0.272905
# REANALYSIS_hpbl_DailyMin                                  -0.234577
# REANALYSIS_shum_2m_DailyMin                                0.420182
# REANALYSIS_windspeed_10m_DailyMin                         -0.055930
# REANALYSIS_prate_DailyMin                                 -0.096703
# REANALYSIS_vis_DailyMin                                    0.262042
# REANALYSIS_hpbl_1Day                                      -0.198038
# REANALYSIS_shum_2m_1Day                                    0.426290
# REANALYSIS_prate_1Day                                     -0.090589
# REANALYSIS_vis_1Day                                        0.272019
# REANALYSIS_air_sfc_DailyMin                                0.464961
# REANALYSIS_air_sfc_DailyMean                               0.593127
# REANALYSIS_air_sfc_DailyMax                                0.700643
# MOD04L2_550                                               -0.123071
# MOD09A1                                                   -0.209404
# MOD11A1_LST_Day_1km_Nearest4                               0.709734
# MOD11A1_LST_Night_1km_Nearest4                             0.592129
# MOD11A1_Clear_day_cov_Nearest4                             0.159208
# MOD11A1_Clear_night_cov_Nearest4                           0.157661
# MOD13A2_Nearest4                                           0.136415
# Nearby_Peak2_NO2                                           0.299528
# Nearby_Peak2_PM25                                          0.108082
# Nearby_Peak2_Ozone                                         0.257122
# Nearby_Peak2Lag1_NO2                                       0.302444
# Nearby_Peak2Lag1_PM25                                      0.130834
# Nearby_Peak2Lag1_Ozone                                     0.217946
# Nearby_Peak2Lag3_NO2                                       0.257392
# Nearby_Peak2Lag3_PM25                                      0.140380
# Nearby_Peak2Lag3_Ozone                                     0.209311
# Nearby_Peak2_MaxTemperature                                0.535589
# Nearby_Peak2_MeanTemperature                               0.474668
# Nearby_Peak2_MinTemperature                                0.387743
# Nearby_Peak2Lag1_MaxTemperature                            0.473090
# Nearby_Peak2Lag1_MeanTemperature                           0.427305
# Nearby_Peak2Lag1_MinTemperature                            0.353521
# Nearby_Peak2Lag3_MaxTemperature                            0.405545
# Nearby_Peak2Lag3_MeanTemperature                           0.382554
# Nearby_Peak2Lag3_MinTemperature                            0.303928
# OMAEROe_UVAerosolIndex_Mean                               -0.058995
# OMAEROe_VISAerosolIndex_Mean                              -0.517906
# OMAERUVd_UVAerosolIndex_Mean                              -0.162557
# OMNO2d_ColumnAmountNO2StratoCloudScreened_Mean             0.423796
# OMO3PR                                                     0.105301
# OMSO2e_ColumnAmountSO2_PBL_Mean                            0.046575
# OMTO3e_ColumnAmountO3                                     -0.643476
# OMUVBd_UVindex_Mean                                        1.000000

# %%
#examples of high correlations
print('correlation, REANALYSIS_air_sfc_DailyMax and OMTO3e_ColumnAmountO3:', corr_matrix['REANALYSIS_air_sfc_DailyMax']['OMTO3e_ColumnAmountO3'])
print('correlation, USElevation_mea100 and USElevation_bln10000:', corr_matrix['USElevation_mea100']['USElevation_bln10000'])
print('correlation, USElevation_bln100 and USElevation_dsc10000:', corr_matrix['USElevation_bln100']['USElevation_dsc10000'])
# Out:
# correlation, REANALYSIS_air_sfc_DailyMax and OMTO3e_ColumnAmountO3: -0.7125604276518227
# correlation, USElevation_mea100 and USElevation_bln10000: 0.992260133874317
# correlation, USElevation_bln100 and USElevation_dsc10000: 0.9926823948245223

# %%
#correlation matrix visualization
fig, ax = plt.subplots(1, 1, figsize = (10, 10))
sns.heatmap(corr_matrix, vmin=-1, vmax=1, center=0, 
            cmap=sns.diverging_palette(20, 220, n=200), 
            square=True, xticklabels=False, yticklabels=False);

# %% [markdown]
# ### Examine pollutant variables

# %% [markdown]
# Next, we examined the three pollutant variables. The histograms and the violinplots of the distributions of these variables suggest that ```PM25_Region``` is trimodal, ```Ozone_Region``` may be bimodal, and ```NO2_Region``` may be multimodal. The three distributions do not seem skewed. The histograms and violinplots indicate that the raw distributions of pollutant variables and the distributions of pollutant variables averaged by site are rather similar. The correlation matrix indicates that the three pollutant variables are not strongly correlated with one another, which is consistent with the 3D scatterplot of these variables that does not show clear relationships among the variables.

# %%
#histograms
fig, ax = plt.subplots(3, 2, figsize = (15, 15))

for i, pollutant in enumerate(['PM25_Region', 'Ozone_Region', 'NO2_Region']):
    ax[i][0].hist(data[pollutant])
    ax[i][0].set_title(f'{pollutant} \n(all observations)')
    ax[i][0].set_xlabel('Pollutant level')
    ax[i][0].set_ylabel('Count')
    
    ax[i][1].hist(data.groupby('site').mean()[pollutant])
    ax[i][1].set_title(f'{pollutant} \n (site average)')
    ax[i][1].set_xlabel('Pollutant level')
    ax[i][1].set_ylabel('Count')

fig.suptitle('Distributions of PM25_Region, Ozone_Region, NO2_Region', y = 1.02)
fig.tight_layout();

# %%
#violin plots

#all observations
fig, ax = plt.subplots(1, 2, figsize = (10, 6))
sns.violinplot(x = 'variable', y = 'value', 
               data = data[['PM25_Region', 'Ozone_Region', 'NO2_Region']].melt(),
              ax=ax[0]);
ax[0].set(xlabel = 'Pollutant', ylabel = 'Pollutant levels', 
          title = 'Distributions of pollutant variables \n(all observations)');

#observations averaged by site
sns.violinplot(x = 'variable', y = 'value', 
               data = data.groupby('site').mean()[['PM25_Region', 'Ozone_Region', 'NO2_Region']].melt(),
               ax=ax[1]);
ax[1].set(xlabel = 'Pollutant', ylabel = 'Pollutant levels', 
          title = 'Distributions of pollutant variables \n(site average)');

# %%
#correlation matrix
data[['PM25_Region', 'Ozone_Region', 'NO2_Region']].corr()
# Out:
#               PM25_Region  Ozone_Region  NO2_Region
# PM25_Region      1.000000      0.079002    0.069612
# Ozone_Region     0.079002      1.000000    0.079404
# NO2_Region       0.069612      0.079404    1.000000

# %%
#3D scatterplot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

xs = data['PM25_Region']
ys = data['Ozone_Region']
zs = data['NO2_Region']
ax.scatter(xs, ys, zs, s = 30, alpha=0.3, edgecolors='w')

ax.set_xlabel('PM25_Region')
ax.set_ylabel('Ozone_Region')
ax.set_zlabel('NO2_Region')

fig.suptitle('3D scatterplot of pollutant variables');

# %%
#overtime

#on average, each day has the EXACT same pollutant levels?
data.groupby('date').mean()[['PM25_Region', 'Ozone_Region', 'NO2_Region']]
# Out:
#       PM25_Region  Ozone_Region  NO2_Region
# date
# 1        0.524069      0.536258    0.526001
# 2        0.524069      0.536258    0.526001
# 3        0.524069      0.536258    0.526001
# 4        0.524069      0.536258    0.526001
# 5        0.524069      0.536258    0.526001
# 6        0.524069      0.536258    0.526001
# 7        0.524069      0.536258    0.526001
# 8        0.524069      0.536258    0.526001
# 9        0.524069      0.536258    0.526001
# 10       0.524069      0.536258    0.526001

# %%
PM25_Region
Ozone_Region
NO2_Region


Nearby_Peak2_NO2
Nearby_Peak2_PM25
Nearby_Peak2_Ozone
Nearby_Peak2Lag1_NO2
Nearby_Peak2Lag1_PM25
Nearby_Peak2Lag1_Ozone
Nearby_Peak2Lag3_NO2
Nearby_Peak2Lag3_PM25
Nearby_Peak2Lag3_Ozone
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-5b20b4f9f332> in <module>
# ----> 1 Nearby_Peak2_NO2
#       2 Nearby_Peak2_PM25
#       3 Nearby_Peak2_Ozone
#       4 Nearby_Peak2Lag1_NO2
#       5 Nearby_Peak2Lag1_PM25
#
# NameError: name 'Nearby_Peak2_NO2' is not defined

# %%
data['PM25_Region'].shape
# Out:
# (21430,)

# %%
# Out:
# Text(0.5, 0, 'NO2_Region')

# %% [markdown]
# ### how an area's pollution is affected by nearby sites  (pollutants variables & nearby monitoring data variables)
